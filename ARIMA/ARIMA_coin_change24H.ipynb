# %%
import pandas as pd

# %%
file_path = '/Users/yoonjiha/Desktop/파란학기/bluesemesterdata/ver-test2'

# %%
df = pd.read_csv(file_path + "/chain-market.csv")
df
# Out:
#                           _time chainName    ath                   athDate  \
# 0      2023-01-22T03:17:05.617Z    cosmos  44.45  2022-01-17T00:34:41.497Z
# 1      2023-01-22T04:00:02.782Z    cosmos  44.45  2022-01-17T00:34:41.497Z
# 2      2023-01-22T05:00:02.824Z    cosmos  44.45  2022-01-17T00:34:41.497Z
# 3      2023-01-22T06:00:03.313Z    cosmos  44.45  2022-01-17T00:34:41.497Z
# 4      2023-01-22T07:00:02.713Z    cosmos  44.45  2022-01-17T00:34:41.497Z
# ...                         ...       ...    ...                       ...
# 10056  2023-05-08T07:00:03.646Z   osmosis  11.25  2022-03-04T05:12:18.707Z
# 10057  2023-05-08T08:00:03.493Z   osmosis  11.25  2022-03-04T05:12:18.707Z
# 10058  2023-05-08T09:00:03.878Z   osmosis  11.25  2022-03-04T05:12:18.707Z
# 10059  2023-05-08T10:00:03.496Z   osmosis  11.25  2022-03-04T05:12:18.707Z
# 10060  2023-05-08T11:00:03.377Z   osmosis  11.25  2022-03-04T05:12:18.707Z
#
#             atl                   atlDate         cap  capChange24h  \
# 0      1.160000  2020-03-13T02:27:44.591Z  3859684388     147701676
# 1      1.160000  2020-03-13T02:27:44.591Z  3907744616     176277536
# 2      1.160000  2020-03-13T02:27:44.591Z  3927643247     184235063
# 3      1.160000  2020-03-13T02:27:44.591Z  3937783620     102299572
# 4      1.160000  2020-03-13T02:27:44.591Z  3924998829     104038978
# ...         ...                       ...         ...           ...
# 10056  0.678606  2023-01-01T05:30:08.710Z   404983121       -133274
# 10057  0.678606  2023-01-01T05:30:08.710Z   403448043       -670280
# 10058  0.678606  2023-01-01T05:30:08.710Z   402169705      -1425917
# 10059  0.678606  2023-01-01T05:30:08.710Z   403875678        753035
# 10060  0.678606  2023-01-01T05:30:08.710Z   400568826      -3936242
#
#        capChangeRatio24H  capRank  ...     low24h      price  \
# 0                3.97905       22  ...  12.710000  13.230000
# 1                4.72408       22  ...  12.740000  13.400000
# 2                4.92159       22  ...  12.790000  13.400000
# 3                2.66719       22  ...  12.930000  13.430000
# 4                2.72285       22  ...  12.930000  13.400000
# ...                  ...      ...  ...        ...        ...
# 10056           -0.03290      103  ...   0.698869   0.702410
# 10057           -0.16586      103  ...   0.698869   0.700059
# 10058           -0.35330      103  ...   0.697954   0.699504
# 10059            0.18680      103  ...   0.696605   0.700127
# 10060           -0.97310      103  ...   0.692537   0.695745
#
#        priceChangePercentage14d  priceChangePercentage1H  \
# 0                     28.957470                -0.485600
# 1                     30.548036                 1.262951
# 2                     30.600500                 0.109195
# 3                     30.878275                -0.008200
# 4                     30.615193                -0.020446
# ...                         ...                      ...
# 10056                 -8.971425                 0.211146
# 10057                 -9.276131                -0.328301
# 10058                 -9.348001                -0.108675
# 10059                 -7.522812                 0.080149
# 10060                 -8.101549                -0.623847
#
#        priceChangePercentage1Y  priceChangePercentage24H  \
# 0                   -66.135479                  4.076443
# 1                   -65.717793                  5.109553
# 2                   -65.704016                  4.756726
# 3                   -65.631072                  2.355746
# 4                   -65.700158                  2.552304
# ...                        ...                       ...
# 10056               -81.515948                 -0.091975
# 10057               -81.577821                 -0.197546
# 10058               -81.592415                 -0.346475
# 10059               -80.316698                 -0.052793
# 10060               -80.439879                 -0.949313
#
#        priceChangePercentage30D  priceChangePercentage7d  supplyCirculating  \
# 0                     49.739968                 6.656563        292586163.8
# 1                     51.586867                 7.972070        292586163.8
# 2                     51.647786                 8.015461        292586163.8
# 3                     51.970326                 8.245199        292586163.8
# 4                     51.664846                 8.027613        292586163.8
# ...                         ...                      ...                ...
# 10056                -10.970256               -10.630145        576419817.0
# 10057                -11.268271               -10.929299        576419817.0
# 10058                -11.338563               -10.999859        576419817.0
# 10059                 -9.789265                -9.837682        576419817.0
# 10060                -10.353819               -10.401932        576419817.0
#
#        totalVolume
# 0        286045792
# 1        270717200
# 2        278476575
# 3        256725694
# 4        248758707
# ...            ...
# 10056      8394496
# 10057      8384778
# 10058      8623022
# 10059      8790759
# 10060      9142674
#
# [10061 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10061 entries, 0 to 10060
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   _time                     10061 non-null  object
#  1   chainName                 10061 non-null  object
#  2   ath                       10061 non-null  float64
#  3   athDate                   10061 non-null  object
#  4   atl                       10061 non-null  float64
#  5   atlDate                   10061 non-null  object
#  6   cap                       10061 non-null  int64
#  7   capChange24h              10061 non-null  int64
#  8   capChangeRatio24H         10061 non-null  float64
#  9   capRank                   10061 non-null  int64
#  10  change24h                 10061 non-null  float64
#  11  changeRatio24H            10061 non-null  float64
#  12  high24h                   10061 non-null  float64
#  13  low24h                    10061 non-null  float64
#  14  price                     10061 non-null  float64
#  15  priceChangePercentage14d  10061 non-null  float64
#  16  priceChangePercentage1H   10061 non-null  float64
#  17  priceChangePercentage1Y   10061 non-null  float64
#  18  priceChangePercentage24H  10061 non-null  float64
#  19  priceChangePercentage30D  10061 non-null  float64
#  20  priceChangePercentage7d   10061 non-null  float64
#  21  supplyCirculating         10061 non-null  float64
#  22  totalVolume               10061 non-null  int64
# dtypes: float64(15), int64(4), object(4)
# memory usage: 1.8+ MB

# %%
df.chainName.unique()
# Out:
# array(['cosmos', 'juno', 'kava', 'osmosis'], dtype=object)

# %%
# Test

# %%
temp = pd.DataFrame()
temp2 = pd.DataFrame()
temp3 = pd.DataFrame()

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(3,1,figsize=(12,8))

temp['date'] = df[df['chainName'] == 'cosmos']['_time'].values
temp['cap'] = df[df['chainName'] == 'cosmos']['capChangeRatio24H'].values
temp.plot(ax=ax[0])

temp2['date'] = df[df['chainName'] == 'cosmos']['_time'].values
temp2['cap'] = df[df['chainName'] == 'cosmos']['changeRatio24H'].values
temp2.plot(ax=ax[1])

temp3['date'] = df[df['chainName'] == 'cosmos']['_time'].values
temp3['cap'] = df[df['chainName'] == 'cosmos']['priceChangePercentage24H'].values
temp3.plot(ax=ax[2])
# Out:
# <Axes: >

# %% [markdown]
# - changeRatio24H, capChangeRatio24H,priceChangePercentage24H 같다

# %%
cos_df = pd.DataFrame()
juno_df = pd.DataFrame()
kava_df = pd.DataFrame()
osmo_df = pd.DataFrame()

# %% [markdown]
# ## 24시간 가격변화량ARIMA 예측

# %% [markdown]
# ### 필요한 데이터만 뽑기

# %%
cos_df['date'] = df[df['chainName'] == 'cosmos']['_time'].values
cos_df['change'] = df[df['chainName'] == 'cosmos']['changeRatio24H'].values

juno_df['date'] = df[df['chainName'] == 'juno']['_time'].values
juno_df['change'] = df[df['chainName'] == 'juno']['changeRatio24H'].values

kava_df['date'] = df[df['chainName'] == 'kava']['_time'].values
kava_df['change'] = df[df['chainName'] == 'kava']['changeRatio24H'].values

osmo_df['date'] = df[df['chainName'] == 'osmosis']['_time'].values
osmo_df['change'] = df[df['chainName'] == 'osmosis']['changeRatio24H'].values

# %%
osmo_df
# Out:
#                           date   change
# 0     2023-01-22T03:17:05.624Z  4.13737
# 1     2023-01-22T04:00:03.054Z  4.98456
# 2     2023-01-22T05:00:03.237Z  5.13152
# 3     2023-01-22T06:00:03.333Z  3.67015
# 4      2023-01-22T07:00:03.08Z  2.66964
# ...                        ...      ...
# 2513  2023-05-08T07:00:03.646Z -0.09197
# 2514  2023-05-08T08:00:03.493Z -0.19755
# 2515  2023-05-08T09:00:03.878Z -0.34647
# 2516  2023-05-08T10:00:03.496Z -0.05279
# 2517  2023-05-08T11:00:03.377Z -0.94931
#
# [2518 rows x 2 columns]

# %%
cos_df['date'] = pd.to_datetime(cos_df['date'])
cos_df = cos_df.set_index('date')
juno_df['date'] = pd.to_datetime(juno_df['date'])
juno_df = juno_df.set_index('date')
kava_df['date'] = pd.to_datetime(kava_df['date'])
kava_df = kava_df.set_index('date')
osmo_df['date'] = pd.to_datetime(osmo_df['date'])
osmo_df = osmo_df.set_index('date')


cos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2516 entries, 2023-01-22 03:17:05.617000+00:00 to 2023-05-08 11:00:03.355000+00:00
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   change  2516 non-null   float64
# dtypes: float64(1)
# memory usage: 39.3 KB

# %%
osmo_df
# Out:
#                                    change
# date
# 2023-01-22 03:17:05.624000+00:00  4.13737
# 2023-01-22 04:00:03.054000+00:00  4.98456
# 2023-01-22 05:00:03.237000+00:00  5.13152
# 2023-01-22 06:00:03.333000+00:00  3.67015
# 2023-01-22 07:00:03.080000+00:00  2.66964
# ...                                   ...
# 2023-05-08 07:00:03.646000+00:00 -0.09197
# 2023-05-08 08:00:03.493000+00:00 -0.19755
# 2023-05-08 09:00:03.878000+00:00 -0.34647
# 2023-05-08 10:00:03.496000+00:00 -0.05279
# 2023-05-08 11:00:03.377000+00:00 -0.94931
#
# [2518 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

# %%
fig, axs = plt.subplots(2,2, figsize=(17,17))
ax1, ax2, ax3, ax4 = axs.flatten()

ax1 = cos_df.plot(ax=ax1)
ax1.set_title('COSMOS')
ax2 = juno_df.plot(ax=ax2)
ax2.set_title('JUNO')
ax3 = kava_df.plot(ax=ax3)
ax3.set_title('KAVA')
ax4 = osmo_df.plot(ax=ax4)
ax4.set_title('OSMOSIS')

plt.show()

# %% [markdown]
# ### 정상성 test

# %%
from statsmodels.tsa.stattools import adfuller

# %%
def adf_test(df):
    result = adfuller(df.values)
    print('ADF Statistics: %f' %result[0])
    print('p-value: %f' %result[1])
    print('Critical values: ')
    for key, value in result[4].items():
        print('\t%s: %.3f' % (key, value))
        
        
print('ADF Test: time series')
adf_test(cos_df)
adf_test(cos_df['change'].diff().dropna())
# Out:
# ADF Test: time series
# ADF Statistics: -6.159606
# p-value: 0.000000
# Critical values:
# 	1%: -3.433
# 	5%: -2.863
# 	10%: -2.567
# ADF Statistics: -18.939913
# p-value: 0.000000
# Critical values:
# 	1%: -3.433
# 	5%: -2.863
# 	10%: -2.567

# %%
adf_test(juno_df['change'])
adf_test(juno_df['change'].diff().dropna())
# Out:
# ADF Statistics: -6.600313
# p-value: 0.000000
# Critical values:
# 	1%: -3.433
# 	5%: -2.863
# 	10%: -2.567
# ADF Statistics: -17.152975
# p-value: 0.000000
# Critical values:
# 	1%: -3.433
# 	5%: -2.863
# 	10%: -2.567

# %%
adf_test(kava_df['change'])
adf_test(kava_df['change'].diff().dropna())
# Out:
# ADF Statistics: -6.119756
# p-value: 0.000000
# Critical values:
# 	1%: -3.433
# 	5%: -2.863
# 	10%: -2.567
# ADF Statistics: -16.966468
# p-value: 0.000000
# Critical values:
# 	1%: -3.433
# 	5%: -2.863
# 	10%: -2.567

# %%
adf_test(osmo_df['change'])
adf_test(osmo_df['change'].diff().dropna())
# Out:
# ADF Statistics: -6.886707
# p-value: 0.000000
# Critical values:
# 	1%: -3.433
# 	5%: -2.863
# 	10%: -2.567
# ADF Statistics: -15.385159
# p-value: 0.000000
# Critical values:
# 	1%: -3.433
# 	5%: -2.863
# 	10%: -2.567

# %%
from statsmodels.tsa.stattools import kpss

# %%
def kpss_test(df):
    statistic, p_value, n_lags, critical_values = kpss(df.values)
    
    print(f'KPSS statistics: {statistic}')
    print(f'p_value: {p_value}')
    print(f'num lags: {n_lags}')
    print('Critial Values: ')
    for key, value in critical_values.items():
        print(f' {key} : {value}')

print('KPSS Test: time series')
kpss_test(cos_df['change'])
kpss_test(cos_df['change'].diff().dropna())
# 0.05보다 작으면 안정적이지 않다는 뜻
# Out:
# KPSS Test: time series
# KPSS statistics: 0.05389763328394335
# p_value: 0.1
# num lags: 29
# Critial Values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# KPSS statistics: 0.0060531578939408024
# p_value: 0.1
# num lags: 10
# Critial Values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:2022: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:2022: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(

# %%
kpss_test(kava_df['change'])
kpss_test(kava_df['change'].diff().dropna())
# Out:
# KPSS statistics: 0.06276401294544447
# p_value: 0.1
# num lags: 29
# Critial Values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# KPSS statistics: 0.006918534400250347
# p_value: 0.1
# num lags: 10
# Critial Values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:2022: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:2022: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(

# %%
kpss_test(juno_df['change'])
kpss_test(juno_df['change'].diff().dropna())
# Out:
# KPSS statistics: 0.3055758909444424
# p_value: 0.1
# num lags: 29
# Critial Values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# KPSS statistics: 0.004091976393781355
# p_value: 0.1
# num lags: 0
# Critial Values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:2022: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:2022: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(

# %%
kpss_test(osmo_df['change'])
kpss_test(osmo_df['change'].diff().dropna())
# Out:
# KPSS statistics: 0.2163981647464465
# p_value: 0.1
# num lags: 29
# Critial Values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# KPSS statistics: 0.005961741605299242
# p_value: 0.1
# num lags: 7
# Critial Values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:2022: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:2022: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
# cap 차분 데이터
diff_series = cos_df.change.diff().dropna()

plt.figure(figsize=(12,12))
plt.subplot(311)
plt.title('COSMO change')
plt.plot(cos_df)
plt.legend('cap data')
plt.subplot(312)
plt.title('COSMO change diff')
plt.plot(diff_series, 'orange')
plt.legend('Diff Data')

# %%
diff_series = juno_df.change.diff().dropna()

plt.figure(figsize=(12,12))
plt.subplot(311)
plt.title('JUNO change')
plt.plot(juno_df)
plt.legend('juno Data')
plt.subplot(312)
plt.title('JUNO change diff')
plt.plot(diff_series, 'orange')
plt.legend('Diff Data')

# %%
diff_series = kava_df.change.diff().dropna()

plt.figure(figsize=(12,12))
plt.subplot(311)
plt.title('KAVA change')
plt.plot(kava_df)
plt.legend('kava Data')
plt.subplot(312)
plt.title('KAVA change diff')
plt.plot(diff_series, 'orange')
plt.legend('Diff Data')

# %%
diff_series = osmo_df.change.diff().dropna()

plt.figure(figsize=(12,12))
plt.subplot(311)
plt.title('OSMOSIS change')
plt.plot(osmo_df)
plt.legend('osmosis Data')
plt.subplot(312)
plt.title('OSMOSIS change diff')
plt.plot(diff_series, 'orange')
plt.legend('Diff Data')

# %% [markdown]
# ### ARIMA 모수 설정

# %%
# !pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in /Users/yoonjiha/anaconda3/lib/python3.10/site-packages (2.0.3)
# Requirement already satisfied: joblib>=0.11 in /Users/yoonjiha/anaconda3/lib/python3.10/site-packages (from pmdarima) (1.1.1)
# Requirement already satisfied: urllib3 in /Users/yoonjiha/anaconda3/lib/python3.10/site-packages (from pmdarima) (1.26.15)
# Requirement already satisfied: scipy>=1.3.2 in /Users/yoonjiha/anaconda3/lib/python3.10/site-packages (from pmdarima) (1.10.0)
# Requirement already satisfied: numpy>=1.21.2 in /Users/yoonjiha/anaconda3/lib/python3.10/site-packages (from pmdarima) (1.23.5)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /Users/yoonjiha/anaconda3/lib/python3.10/site-packages (from pmdarima) (65.6.3)
# Requirement already satisfied: pandas>=0.19 in /Users/yoonjiha/anaconda3/lib/python3.10/site-packages (from pmdarima) (1.5.3)
# Requirement already satisfied: statsmodels>=0.13.2 in /Users/yoonjiha/anaconda3/lib/python3.10/site-packages (from pmdarima) (0.13.5)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /Users/yoonjiha/anaconda3/lib/python3.10/site-packages (from pmdarima) (0.29.34)
# Requirement already satisfied: scikit-learn>=0.22 in /Users/yoonjiha/anaconda3/lib/python3.10/site-packages (from pmdarima) (1.2.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/yoonjiha/anaconda3/lib/python3.10/site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/yoonjiha/anaconda3/lib/python3.10/site-packages (from pandas>=0.19->pmdarima) (2022.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/yoonjiha/anaconda3/lib/python3.10/site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: packaging>=21.3 in /Users/yoonjiha/anaconda3/lib/python3.10/site-packages (from statsmodels>=0.13.2->pmdarima) (22.0)
# Requirement already satisfied: patsy>=0.5.2 in /Users/yoonjiha/anaconda3/lib/python3.10/site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: six in /Users/yoonjiha/anaconda3/lib/python3.10/site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.12.0)

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %% [markdown]
# ### COSMOS ARIMA

# %%
plot_acf(cos_df)
plot_pacf(cos_df)
plt.show()
# Out:
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
diff_1=cos_df.diff(periods=1).iloc[1:]
diff_1.plot()
plot_acf(diff_1)
plot_pacf(diff_1)
plt.show()
# Out:
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
from pmdarima.arima import auto_arima

# 파라미터 값 찾기
model_arima = auto_arima(cos_df,trace=True, error_action='ignore', start_p=1,start_q=1,max_p=3,max_q=3,suppress_warnings=True,stepwise=False,seasonal=False)

model_arima.fit(cos_df)
# Out:
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=13143.651, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=10746.478, Time=0.14 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=9419.173, Time=0.42 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=8759.851, Time=0.48 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=7432.674, Time=0.10 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=7433.458, Time=0.16 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=7430.618, Time=0.13 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=7431.471, Time=0.29 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=7433.341, Time=0.14 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=7436.360, Time=0.48 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=7423.504, Time=0.59 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=7425.049, Time=0.96 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=7430.133, Time=0.13 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=7423.490, Time=0.71 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=7424.384, Time=0.91 sec
#
# Best model:  ARIMA(3,0,1)(0,0,0)[0]
# Total fit time: 5.687 seconds
# ARIMA(order=(3, 0, 1), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(cos_df, test_size=0.2, shuffle=False)

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_predict
import statsmodels.api as sm
import sys

model = SARIMAX(train_df, order=(3,0,1), trend='t')
# trend = t: 시간에 따른 추세 변화 모델링

model_fit = model.fit(full_output = True, disp = 1)
print(model_fit.summary())
# Out:
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.50650D+00    |proj g|=  2.43795D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6      1     21      1     0     0   2.438D+00   1.506D+00
#   F =   1.5064951478738500
#
# ABNORMAL_TERMINATION_IN_LNSRCH
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 change   No. Observations:                 2012
# Model:               SARIMAX(3, 0, 1)   Log Likelihood               -3031.068
# Date:                Thu, 18 May 2023   AIC                           6074.136
# Time:                        23:31:33   BIC                           6107.778
# Sample:                             0   HQIC                          6086.485
#                                - 2012
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# drift       4.032e-06   2.89e-05      0.139      0.889   -5.27e-05    6.07e-05
# ar.L1          0.6430      0.379      1.695      0.090      -0.101       1.387
# ar.L2          0.3339      0.360      0.927      0.354      -0.372       1.040
# ar.L3         -0.0509      0.020     -2.579      0.010      -0.089      -0.012
# ma.L1          0.3202      0.378      0.846      0.398      -0.422       1.062
# sigma2         1.1878      0.022     54.934      0.000       1.145       1.230
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              1441.48
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.80   Skew:                             0.09
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.14
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
fig, ax = plt.subplots()
fig = plot_predict(model_fit, ax = ax)# 학습데이터 예측 결과
res = pd.DataFrame(model_fit.resid)# 잔차 변동 시각화
res.plot()
# Out:
# <Axes: xlabel='date'>

# %%
# test 데이터 개수만큼 예측값 뽑기
fore = model_fit.get_forecast(steps=len(test_df.index), alpha=0.05).summary_frame()
fore
# Out:
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# change      mean   mean_se  mean_ci_lower  mean_ci_upper
# 2012   -0.935906  1.089880      -3.072031       1.200219
# 2013   -1.009302  1.513206      -3.975130       1.956527
# 2014   -0.908730  1.835471      -4.506187       2.688727
# 2015   -0.865539  2.072749      -4.928053       3.196974
# 2016   -0.800454  2.264764      -5.239309       3.638401
# ...          ...       ...            ...            ...
# 2511    0.135938  3.387742      -6.503915       6.775790
# 2512    0.135992  3.387742      -6.503860       6.775845
# 2513    0.136047  3.387742      -6.503806       6.775899
# 2514    0.136101  3.387742      -6.503751       6.775954
# 2515    0.136156  3.387742      -6.503697       6.776008
#
# [504 rows x 4 columns]

# %%
fc = tuple(fore['mean'].values) # 예측값
se = tuple(fore['mean_se'].values) # 표준오차
lower_coef = tuple(fore['mean_ci_lower'].values) # 신뢰구간 최소
upper_coef = tuple(fore['mean_ci_upper'].values) # 신뢰구간 최대

# 예측값 인덱스 넣기
fc_data = pd.Series(fc, index = test_df.index)

# 신뢰구간 인덱스 넣기
lower_data = pd.Series(lower_coef, index = test_df.index)
upper_data = pd.Series(upper_coef, index = test_df.index )

# %%
#시각화 
plt.figure(figsize =(15, 6))
plt.plot(train_df, label = 'training')
plt.plot(test_df, label = 'actual')
plt.plot(fc_data, label = 'forecast')
plt.fill_between(test_df.index, lower_data, upper_data, color = 'black', alpha = 0.1)
plt.legend(loc = 'upper left')
plt.show()

# %% [markdown]
# ### JUNO ARIMA

# %%
plot_acf(juno_df)
plot_pacf(juno_df)
plt.show()
# Out:
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
diff_1=juno_df.diff(periods=1).iloc[1:]
diff_1.plot()
plot_acf(diff_1)
plot_pacf(diff_1)
plt.show()
# Out:
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
from pmdarima.arima import auto_arima

# 파라미터 값 찾기
model_arima = auto_arima(juno_df,trace=True, error_action='ignore', start_p=1,start_q=1,max_p=3,max_q=3,suppress_warnings=True,stepwise=False,seasonal=False)

model_arima.fit(juno_df)
# Out:
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=7982.481, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=7972.572, Time=0.14 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=7974.550, Time=0.20 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=7975.628, Time=0.26 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=7972.587, Time=0.14 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=7974.557, Time=0.17 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=7975.943, Time=0.78 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=7977.338, Time=0.74 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=7974.543, Time=0.16 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=7976.554, Time=0.25 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=7976.444, Time=1.57 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=7953.570, Time=3.18 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=7975.898, Time=0.22 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=7977.401, Time=0.76 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=7940.282, Time=2.70 sec
#
# Best model:  ARIMA(3,1,2)(0,0,0)[0] intercept
# Total fit time: 11.348 seconds
# ARIMA(order=(3, 1, 2), scoring_args={}, suppress_warnings=True)

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(juno_df, test_size=0.2, shuffle=False)

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_predict
import statsmodels.api as sm
import sys

model = SARIMAX(train_df, order=(3,1,2), trend='t')
# trend = t: 시간에 따른 추세 변화 모델링

model_fit = model.fit(full_output = True, disp = 1)
print(model_fit.summary())
# Out:
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.63556D+00    |proj g|=  4.11887D+00
#
# At iterate    1    f=  1.63556D+00    |proj g|=  4.08032D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7      1     13      1     0     0   4.080D+00   1.636D+00
#   F =   1.6355571337544701
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 change   No. Observations:                 2006
# Model:               SARIMAX(3, 1, 2)   Log Likelihood               -3280.928
# Date:                Thu, 18 May 2023   AIC                           6575.855
# Time:                        23:35:49   BIC                           6615.079
# Sample:                             0   HQIC                          6590.256
#                                - 2006
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# drift       2.255e-07   2.75e-05      0.008      0.993   -5.38e-05    5.42e-05
# ar.L1          0.8817      0.018     49.657      0.000       0.847       0.916
# ar.L2         -0.9125      0.019    -47.352      0.000      -0.950      -0.875
# ar.L3         -0.0612      0.019     -3.259      0.001      -0.098      -0.024
# ma.L1         -0.9655      0.003   -340.199      0.000      -0.971      -0.960
# ma.L2          0.9949      0.003    320.720      0.000       0.989       1.001
# sigma2         1.5512      0.029     53.689      0.000       1.495       1.608
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):              1716.10
# Prob(Q):                              0.88   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.63   Skew:                            -0.07
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.53
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.

# %%
fig, ax = plt.subplots()
fig = plot_predict(model_fit, ax = ax)# 학습데이터 예측 결과
res = pd.DataFrame(model_fit.resid)# 잔차 변동 시각화
res.plot()
# Out:
# <Axes: xlabel='date'>

# %%
# test 데이터 개수만큼 예측값 뽑기
fore = model_fit.get_forecast(steps=len(test_df.index), alpha=0.05).summary_frame()
fore
# Out:
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# change      mean    mean_se  mean_ci_lower  mean_ci_upper
# 2006   -0.055374   1.245459      -2.496429       2.385681
# 2007   -0.109561   1.689108      -3.420151       3.201029
# 2008   -0.091906   2.044351      -4.098761       3.914950
# 2009   -0.018909   2.360484      -4.645373       4.607556
# 2010    0.033113   2.648807      -5.158452       5.224679
# ...          ...        ...            ...            ...
# 2503    0.193021  26.201990     -51.161936      51.547978
# 2504    0.193501  26.228280     -51.212983      51.599985
# 2505    0.193953  26.254542     -51.264004      51.651911
# 2506    0.194446  26.280778     -51.314933      51.703824
# 2507    0.195003  26.306988     -51.365746      51.755752
#
# [502 rows x 4 columns]

# %%
fc = tuple(fore['mean'].values) # 예측값
se = tuple(fore['mean_se'].values) # 표준오차
lower_coef = tuple(fore['mean_ci_lower'].values) # 신뢰구간 최소
upper_coef = tuple(fore['mean_ci_upper'].values) # 신뢰구간 최대

# 예측값 인덱스 넣기
fc_data = pd.Series(fc, index = test_df.index)

# 신뢰구간 인덱스 넣기
lower_data = pd.Series(lower_coef, index = test_df.index)
upper_data = pd.Series(upper_coef, index = test_df.index )

# %%
#시각화 
plt.figure(figsize =(15, 6))
plt.plot(train_df, label = 'training')
plt.plot(test_df, label = 'actual')
plt.plot(fc_data, label = 'forecast')
plt.fill_between(test_df.index, lower_data, upper_data, color = 'black', alpha = 0.1)
plt.legend(loc = 'upper left')
plt.show()

# %% [markdown]
# ### KAVA ARIMA

# %%
plot_acf(kava_df)
plot_pacf(kava_df)
plt.show()
# Out:
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
diff_1=kava_df.diff(periods=1).iloc[1:]
diff_1.plot()
plot_acf(diff_1)
plot_pacf(diff_1)
plt.show()
# Out:
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
from pmdarima.arima import auto_arima

# 파라미터 값 찾기
model_arima = auto_arima(kava_df,trace=True, error_action='ignore', start_p=1,start_q=1,max_p=3,max_q=3,suppress_warnings=True,stepwise=False,seasonal=False)

model_arima.fit(kava_df)
# Out:
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=14617.317, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=12242.317, Time=0.12 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=10968.509, Time=0.28 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=10308.367, Time=0.42 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=8929.567, Time=0.09 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=8929.955, Time=0.13 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=8931.434, Time=0.20 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=8931.051, Time=0.26 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=8929.909, Time=0.12 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=8931.880, Time=0.15 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=8933.806, Time=0.37 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=8923.846, Time=1.05 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=8931.512, Time=0.14 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=8933.800, Time=0.21 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=8924.637, Time=1.16 sec
#
# Best model:  ARIMA(2,0,3)(0,0,0)[0]
# Total fit time: 4.755 seconds
# ARIMA(order=(2, 0, 3), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(kava_df, test_size=0.2, shuffle=False)

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_predict
import statsmodels.api as sm
import sys

model = SARIMAX(train_df, order=(2,0,3), trend='t')
# trend = t: 시간에 따른 추세 변화 모델링

model_fit = model.fit(full_output = True, disp = 1)
print(model_fit.summary())
# Out:
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.80792D+00    |proj g|=  1.21647D+01
#
# At iterate    1    f=  1.80792D+00    |proj g|=  8.99370D+00
#
# At iterate    2    f=  1.80792D+00    |proj g|=  7.26038D+00
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7      3     46      2     0     0   7.260D+00   1.808D+00
#   F =   1.8079180908732886
#
# ABNORMAL_TERMINATION_IN_LNSRCH
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 change   No. Observations:                 2015
# Model:               SARIMAX(2, 0, 3)   Log Likelihood               -3642.955
# Date:                Thu, 18 May 2023   AIC                           7299.910
# Time:                        23:38:30   BIC                           7339.169
# Sample:                             0   HQIC                          7314.319
#                                - 2015
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# drift       4.287e-06   1.92e-05      0.224      0.823   -3.33e-05    4.18e-05
# ar.L1          1.3254      0.526      2.518      0.012       0.294       2.357
# ar.L2         -0.3594      0.500     -0.719      0.472      -1.339       0.620
# ma.L1         -0.4265      0.527     -0.809      0.418      -1.459       0.606
# ma.L2          0.0291      0.035      0.830      0.407      -0.040       0.098
# ma.L3          0.0302      0.024      1.246      0.213      -0.017       0.078
# sigma2         2.1700      0.038     57.464      0.000       2.096       2.244
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              1977.54
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.76   Skew:                             0.14
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.84
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.

# %%
fig, ax = plt.subplots()
fig = plot_predict(model_fit, ax = ax)# 학습데이터 예측 결과
res = pd.DataFrame(model_fit.resid)# 잔차 변동 시각화
res.plot()
# Out:
# <Axes: xlabel='date'>

# %%
# test 데이터 개수만큼 예측값 뽑기
fore = model_fit.get_forecast(steps=len(test_df.index), alpha=0.05).summary_frame()
fore
# Out:
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# change      mean   mean_se  mean_ci_lower  mean_ci_upper
# 2015    0.334256  1.473088      -2.552943       3.221456
# 2016    0.296161  1.980768      -3.586074       4.178395
# 2017    0.267432  2.352099      -4.342598       4.877462
# 2018    0.256664  2.663534      -4.963767       5.477096
# 2019    0.252723  2.921633      -5.473573       5.979018
# ...          ...       ...            ...            ...
# 2514    0.314733  4.566029      -8.634519       9.263985
# 2515    0.314859  4.566029      -8.634393       9.264111
# 2516    0.314985  4.566029      -8.634266       9.264237
# 2517    0.315111  4.566029      -8.634140       9.264363
# 2518    0.315238  4.566029      -8.634014       9.264489
#
# [504 rows x 4 columns]

# %%
fc = tuple(fore['mean'].values) # 예측값
se = tuple(fore['mean_se'].values) # 표준오차
lower_coef = tuple(fore['mean_ci_lower'].values) # 신뢰구간 최소
upper_coef = tuple(fore['mean_ci_upper'].values) # 신뢰구간 최대

# 예측값 인덱스 넣기
fc_data = pd.Series(fc, index = test_df.index)

# 신뢰구간 인덱스 넣기
lower_data = pd.Series(lower_coef, index = test_df.index)
upper_data = pd.Series(upper_coef, index = test_df.index )

# %%
#시각화 
plt.figure(figsize =(15, 6))
plt.plot(train_df, label = 'training')
plt.plot(test_df, label = 'actual')
plt.plot(fc_data, label = 'forecast')
plt.fill_between(test_df.index, lower_data, upper_data, color = 'black', alpha = 0.1)
plt.legend(loc = 'upper left')
plt.show()

# %% [markdown]
# ### OSMOSIS ARIMA

# %%
plot_acf(osmo_df)
plot_pacf(osmo_df)
plt.show()
# Out:
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
diff_1=osmo_df.diff(periods=1).iloc[1:]
diff_1.plot()
plot_acf(diff_1)
plot_pacf(diff_1)
plt.show()
# Out:
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
from pmdarima.arima import auto_arima

# 파라미터 값 찾기
model_arima = auto_arima(osmo_df,trace=True, error_action='ignore', start_p=1,start_q=1,max_p=5,max_q=5,suppress_warnings=True,stepwise=False,seasonal=False)

model_arima.fit(osmo_df)
# Out:
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=7565.692, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=7549.575, Time=0.14 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=7549.961, Time=0.22 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=7549.462, Time=0.26 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=7551.453, Time=0.36 sec
#  ARIMA(0,1,5)(0,0,0)[0] intercept   : AIC=7550.004, Time=0.45 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=7548.890, Time=0.16 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=7550.664, Time=0.40 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=7550.769, Time=0.55 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=7551.459, Time=0.66 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=7552.396, Time=0.89 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=7550.496, Time=0.19 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=7551.372, Time=0.71 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=7524.353, Time=2.49 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=2.73 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=7549.721, Time=0.20 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=7551.617, Time=0.58 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=2.62 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=7551.361, Time=0.26 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=7551.512, Time=1.05 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=7548.742, Time=0.32 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0] intercept
# Total fit time: 15.305 seconds
# ARIMA(order=(2, 1, 2), scoring_args={}, suppress_warnings=True)

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(osmo_df, test_size=0.2, shuffle=False)

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_predict
import statsmodels.api as sm
import sys

model = SARIMAX(train_df, order=(2,1,2), trend='t')
# trend = t: 시간에 따른 추세 변화 모델링

model_fit = model.fit(full_output = True, disp = 1)
print(model_fit.summary())
# Out:
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.55625D+00    |proj g|=  2.85703D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6      1     21      1     0     0   2.857D+00   1.556D+00
#   F =   1.5562538346655945
#
# ABNORMAL_TERMINATION_IN_LNSRCH
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 change   No. Observations:                 2014
# Model:               SARIMAX(2, 1, 2)   Log Likelihood               -3134.295
# Date:                Thu, 18 May 2023   AIC                           6280.590
# Time:                        23:44:56   BIC                           6314.235
# Sample:                             0   HQIC                          6292.940
#                                - 2014
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# drift       1.824e-07   4.05e-05      0.005      0.996   -7.92e-05    7.96e-05
# ar.L1         -0.1067      0.348     -0.307      0.759      -0.788       0.575
# ar.L2         -0.3268      0.126     -2.584      0.010      -0.575      -0.079
# ma.L1         -0.0029      0.348     -0.008      0.993      -0.685       0.679
# ma.L2          0.3378      0.133      2.543      0.011       0.077       0.598
# sigma2         1.3158      0.010    126.651      0.000       1.295       1.336
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):             95338.48
# Prob(Q):                              0.89   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.25   Skew:                             0.36
# Prob(H) (two-sided):                  0.00   Kurtosis:                        36.71
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.

# %%
fig, ax = plt.subplots()
fig = plot_predict(model_fit, ax = ax)# 학습데이터 예측 결과
res = pd.DataFrame(model_fit.resid)# 잔차 변동 시각화
res.plot()
# Out:
# <Axes: xlabel='date'>

# %%
# test 데이터 개수만큼 예측값 뽑기
fore = model_fit.get_forecast(steps=len(test_df.index), alpha=0.05).summary_frame()
fore
# Out:
# /Users/yoonjiha/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# change      mean    mean_se  mean_ci_lower  mean_ci_upper
# 2014    0.348586   1.147064      -1.899618       2.596790
# 2015    0.295991   1.535818      -2.714157       3.306139
# 2016    0.269960   1.858955      -3.373525       3.913445
# 2017    0.290292   2.152773      -3.929065       4.509650
# 2018    0.296996   2.405391      -4.417484       5.011477
# ...          ...        ...            ...            ...
# 2513    0.433226  23.886003     -46.382480      47.248931
# 2514    0.433546  23.909874     -46.428946      47.296037
# 2515    0.433866  23.933721     -46.475366      47.343097
# 2516    0.434186  23.957545     -46.521739      47.390111
# 2517    0.434506  23.981345     -46.568066      47.437078
#
# [504 rows x 4 columns]

# %%
fc = tuple(fore['mean'].values) # 예측값
se = tuple(fore['mean_se'].values) # 표준오차
lower_coef = tuple(fore['mean_ci_lower'].values) # 신뢰구간 최소
upper_coef = tuple(fore['mean_ci_upper'].values) # 신뢰구간 최대

# 예측값 인덱스 넣기
fc_data = pd.Series(fc, index = test_df.index)

# 신뢰구간 인덱스 넣기
lower_data = pd.Series(lower_coef, index = test_df.index)
upper_data = pd.Series(upper_coef, index = test_df.index )

# %%
#시각화 
plt.figure(figsize =(15, 6))
plt.plot(train_df, label = 'training')
plt.plot(test_df, label = 'actual')
plt.plot(fc_data, label = 'forecast')
plt.fill_between(test_df.index, lower_data, upper_data, color = 'black', alpha = 0.1)
plt.legend(loc = 'upper left')
plt.show()

# %% [markdown]
# ### 결론
# - ARIMA로 가격/가격변화율을 예측하는 데에는 한계가 있다.
# - 그래도 가격보다는 가격변화율 데이터가 정상성을 갖고 있으며 ARIMA 모델에 적합한 데이터였다.
# - 가격변화율 데이터는 ARIMA 모델에서 예측력은 p-value가 낮게 나오며 AIC, BIC 값도 상대적으로 적게 나와 유의미하다고 해석할 수 있었지만, 막상 실제 데이터와 비교해보니 제대로 된 예측을 하지는 못한다는 것을 알 수 있었다.
# - 가격변화율 중에서도 1시간 < 7일 < 1일 순으로 대략적 흐름은 예측력이 있었다.
# - 가격이나 가격변화율을 예측하는 데에는 이 데이터 말고도 다른 요소들이 필요하기 때문인 것 같다.
