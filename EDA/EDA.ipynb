# %%
import pandas as pd

# %%
file_path = '/Users/yoonjiha/Desktop/파란학기/bluesemesterdata'

# %%
data = pd.read_csv(file_path + "/atom-chain-info.csv")
data
# Out:
#                          _time chainName  activeValidators       apr  \
# 0     2023-01-22T03:17:05.617Z    cosmos               175  0.210049
# 1     2023-01-22T04:00:02.782Z    cosmos               175  0.210052
# 2     2023-01-22T05:00:02.824Z    cosmos               175  0.210068
# 3     2023-01-22T06:00:03.313Z    cosmos               175  0.210078
# 4     2023-01-22T07:00:02.713Z    cosmos               175  0.210048
# ...                        ...       ...               ...       ...
# 1939  2023-04-14T09:59:01.944Z    cosmos               175  0.213393
# 1940  2023-04-14T10:59:01.968Z    cosmos               175  0.213393
# 1941  2023-04-14T12:00:03.586Z    cosmos               175  0.213534
# 1942  2023-04-14T13:00:03.269Z    cosmos               175  0.213539
# 1943  2023-04-14T14:00:03.665Z    cosmos               175  0.213528
#
#       blockHeight  blockTime  bondedTokens  communityTokens  inflation  \
# 0        13763706   6.712609  2.030900e+14     1.785360e+12   0.145679
# 1        13764094   6.704481  2.030980e+14     1.785760e+12   0.145685
# 2        13764628   6.704578  2.030980e+14     1.786340e+12   0.145694
# 3        13765163   6.695375  2.031040e+14     1.786930e+12   0.145702
# 4        13765697   6.691821  2.031480e+14     1.787510e+12   0.145710
# ...           ...        ...           ...              ...        ...
# 1939     14878165   6.318232  2.304260e+14     2.252410e+12   0.161404
# 1940     14878738   6.316701  2.304270e+14     2.253130e+12   0.161402
# 1941     14879318   6.314835  2.302780e+14     2.253840e+12   0.161400
# 1942     14879889   6.313771  2.302750e+14     2.254560e+12   0.161398
# 1943     14880463   6.310315  2.302880e+14     2.255280e+12   0.161396
#
#       jailedValidators  supplyTokens  totalValidators       tps       txs
# 0                  325  3.253640e+14              500  0.605406  28947601
# 1                  325  3.253680e+14              500  0.637318  28949188
# 2                  325  3.253740e+14              500  0.516218  28951287
# 3                  325  3.253800e+14              500  0.581966  28953224
# 4                  325  3.253850e+14              500  0.344477  28954946
# ...                ...           ...              ...       ...       ...
# 1939               338  3.384960e+14              513  0.643133  32628952
# 1940               338  3.385040e+14              513  0.514075  32630703
# 1941               338  3.385110e+14              513  0.411382  32632309
# 1942               338  3.385180e+14              513  0.370364  32633732
# 1943               338  3.385250e+14              513  0.442055  32635173
#
# [1944 rows x 14 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1944 entries, 0 to 1943
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _time             1944 non-null   object
#  1   chainName         1944 non-null   object
#  2   activeValidators  1944 non-null   int64
#  3   apr               1944 non-null   float64
#  4   blockHeight       1944 non-null   int64
#  5   blockTime         1944 non-null   float64
#  6   bondedTokens      1944 non-null   float64
#  7   communityTokens   1944 non-null   float64
#  8   inflation         1944 non-null   float64
#  9   jailedValidators  1944 non-null   int64
#  10  supplyTokens      1944 non-null   float64
#  11  totalValidators   1944 non-null   int64
#  12  tps               1944 non-null   float64
#  13  txs               1944 non-null   int64
# dtypes: float64(7), int64(5), object(2)
# memory usage: 212.8+ KB

# %%
data.isnull().sum()
# Out:
# _time               0
# chainName           0
# activeValidators    0
# apr                 0
# blockHeight         0
# blockTime           0
# bondedTokens        0
# communityTokens     0
# inflation           0
# jailedValidators    0
# supplyTokens        0
# totalValidators     0
# tps                 0
# txs                 0
# dtype: int64

# %%
data.describe()
# Out:
#        activeValidators          apr   blockHeight    blockTime  bondedTokens  \
# count       1944.000000  1944.000000  1.944000e+03  1944.000000  1.944000e+03
# mean         172.839506     0.221708  1.432286e+07     6.377759  2.086766e+14
# std           19.329016     0.010212  3.221732e+05     0.128916  9.469808e+12
# min            0.000000     0.000000  1.376371e+07     6.252963  1.964100e+14
# 25%          175.000000     0.214071  1.404770e+07     6.292847  2.025915e+14
# 50%          175.000000     0.218415  1.432258e+07     6.336130  2.067225e+14
# 75%          175.000000     0.231532  1.460073e+07     6.390198  2.084572e+14
# max          175.000000     0.234980  1.488046e+07     6.797856  2.306080e+14
#
#        communityTokens    inflation  jailedValidators  supplyTokens  \
# count     1.944000e+03  1944.000000       1944.000000  1.944000e+03
# mean      1.843169e+12     0.154763        332.956790  3.317787e+14
# std       2.026127e+11     0.006451          4.387695  3.800665e+12
# min       0.000000e+00     0.000000        325.000000  3.253640e+14
# 25%       1.673912e+12     0.149942        329.000000  3.285122e+14
# 50%       1.839040e+12     0.155010        333.000000  3.316775e+14
# 75%       2.002625e+12     0.160524        337.000000  3.350358e+14
# max       2.255280e+12     0.161739        338.000000  3.385250e+14
#
#        totalValidators          tps           txs
# count      1944.000000  1944.000000  1.944000e+03
# mean        505.796296     0.553745  3.085483e+07
# std          20.670308     0.241129  1.084606e+06
# min         325.000000     0.106752  2.894760e+07
# 25%         504.000000     0.410084  2.991446e+07
# 50%         508.000000     0.530453  3.092178e+07
# 75%         512.000000     0.657802  3.179002e+07
# max         513.000000     5.257829  3.263517e+07

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 확률밀도함수+히스토그램

# %%
sns.distplot(data['communityTokens'],kde=True, hist=True)
plt.show()
# Out:
# /var/folders/rz/fqp0nbd52px3k0c93ldtw5fh0000gn/T/ipykernel_33553/2812623275.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['communityTokens'],kde=True, hist=True)

# %%
sns.distplot(data['apr'],kde=True, hist=True)
plt.show()
# Out:
# /var/folders/rz/fqp0nbd52px3k0c93ldtw5fh0000gn/T/ipykernel_33553/4095983059.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['apr'],kde=True, hist=True)

# %%
sns.distplot(data['tps'],kde=True, hist=True)
plt.show()
# Out:
# /var/folders/rz/fqp0nbd52px3k0c93ldtw5fh0000gn/T/ipykernel_33553/2310219605.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['tps'],kde=True, hist=True)

# %% [markdown]
# ### 라인 차트

# %%
sns.lineplot(x='_time', y = 'apr', data= data)
# Out:
# <Axes: xlabel='_time', ylabel='apr'>

# %%
sns.lineplot(x='_time', y = 'communityTokens', data= data)
# Out:
# <Axes: xlabel='_time', ylabel='communityTokens'>

# %%
sns.lineplot(x='_time', y = 'tps', data= data)
# Out:
# <Axes: xlabel='_time', ylabel='tps'>

# %% [markdown]
# ### 회귀선 + 산점도

# %%
sns.regplot(x='communityTokens', y='apr', data=data)
# Out:
# <Axes: xlabel='communityTokens', ylabel='apr'>

# %%
sns.regplot(x='communityTokens', y='tps', data=data)
# Out:
# <Axes: xlabel='communityTokens', ylabel='tps'>

# %%
sns.regplot(x='apr', y='tps', data=data)
# Out:
# <Axes: xlabel='apr', ylabel='tps'>

# %%
df = pd.read_csv(file_path + "/atom-chain-market-btc.csv")
df
# Out:
#                          _time chainName       ath                   athDate  \
# 0     2023-01-24T21:00:02.905Z    cosmos  0.001654  2019-03-15T00:00:00.000Z
# 1     2023-01-24T22:00:02.787Z    cosmos  0.001654  2019-03-15T00:00:00.000Z
# 2     2023-01-24T23:00:02.815Z    cosmos  0.001654  2019-03-15T00:00:00.000Z
# 3      2023-01-25T00:00:02.82Z    cosmos  0.001654  2019-03-15T00:00:00.000Z
# 4     2023-01-25T01:00:02.585Z    cosmos  0.001654  2019-03-15T00:00:00.000Z
# ...                        ...       ...       ...                       ...
# 1878  2023-04-14T09:59:01.944Z    cosmos  0.001654  2019-03-15T00:00:00.000Z
# 1879  2023-04-14T10:59:01.968Z    cosmos  0.001654  2019-03-15T00:00:00.000Z
# 1880  2023-04-14T12:00:03.586Z    cosmos  0.001654  2019-03-15T00:00:00.000Z
# 1881  2023-04-14T13:00:03.269Z    cosmos  0.001654  2019-03-15T00:00:00.000Z
# 1882  2023-04-14T14:00:03.665Z    cosmos  0.001654  2019-03-15T00:00:00.000Z
#
#            atl                   atlDate     cap  capChange24h  \
# 0     0.000143  2021-01-08T16:59:22.387Z  166960         -3446
# 1     0.000143  2021-01-08T16:59:22.387Z  166800         -2635
# 2     0.000143  2021-01-08T16:59:22.387Z  166823         -1314
# 3     0.000143  2021-01-08T16:59:22.387Z  166691         -1009
# 4     0.000143  2021-01-08T16:59:22.387Z  166581          -469
# ...        ...                       ...     ...           ...
# 1878  0.000143  2021-01-08T16:59:22.387Z  113974          3953
# 1879  0.000143  2021-01-08T16:59:22.387Z  114282          4436
# 1880  0.000143  2021-01-08T16:59:22.387Z  114110          4124
# 1881  0.000143  2021-01-08T16:59:22.387Z  114812          4730
# 1882  0.000143  2021-01-08T16:59:22.387Z  115040          4692
#
#       capChangeRatio24H  capRank  ...    low24h     price  \
# 0              -2.02179       22  ...  0.000564  0.000571
# 1              -1.55467       22  ...  0.000564  0.000570
# 2              -0.78117       22  ...  0.000564  0.000568
# 3              -0.60135       22  ...  0.000564  0.000570
# 4              -0.28030       22  ...  0.000564  0.000569
# ...                 ...      ...  ...       ...       ...
# 1878            3.59299       22  ...  0.000375  0.000389
# 1879            4.03805       22  ...  0.000375  0.000390
# 1880            3.74972       22  ...  0.000376  0.000391
# 1881            4.29717       22  ...  0.000376  0.000393
# 1882            4.25232       22  ...  0.000377  0.000393
#
#       priceChangePercentage14d  priceChangePercentage1H  \
# 0                   -11.728592                -0.387103
# 1                   -11.873254                -0.163883
# 2                   -12.106786                -0.311488
# 3                   -11.795122                 0.207083
# 4                   -12.000431                -0.232633
# ...                        ...                      ...
# 1878                 -2.120972                 0.079521
# 1879                 -1.816000                 0.284601
# 1880                 -1.776295                 0.029045
# 1881                 -1.273160                 0.781308
# 1882                 -1.111393                 0.179739
#
#       priceChangePercentage1Y  priceChangePercentage24H  \
# 0                  -39.836962                 -2.099227
# 1                  -39.935559                 -1.562347
# 2                  -40.094728                 -1.129985
# 3                  -39.882307                 -1.043783
# 4                  -40.022240                 -0.193819
# ...                       ...                       ...
# 1878               -35.217581                  3.501993
# 1879               -35.015732                  3.844090
# 1880               -34.989453                  3.856375
# 1881               -34.656446                  4.385583
# 1882               -34.549379                  4.232735
#
#       priceChangePercentage30D  priceChangePercentage7d  supplyCirculating  \
# 0                     7.189271                -1.942888        292586163.8
# 1                     7.013606                -2.103587        292586163.8
# 2                     6.730024                -2.363008        292586163.8
# 3                     7.108483                -2.016792        292586163.8
# 4                     6.859172                -2.244863        292586163.8
# ...                        ...                      ...                ...
# 1878                -26.240107                -3.667876        292586163.8
# 1879                -26.010285                -3.367724        292586163.8
# 1880                -25.980365                -3.328647        292586163.8
# 1881                -25.601211                -2.833463        292586163.8
# 1882                -25.479306                -2.674253        292586163.8
#
#       totalVolume
# 0            8186
# 1            7855
# 2            7734
# 3            7421
# 4            7003
# ...           ...
# 1878         5881
# 1879         6045
# 1880         6223
# 1881         6320
# 1882         6391
#
# [1883 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1883 entries, 0 to 1882
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   _time                     1883 non-null   object
#  1   chainName                 1883 non-null   object
#  2   ath                       1883 non-null   float64
#  3   athDate                   1883 non-null   object
#  4   atl                       1883 non-null   float64
#  5   atlDate                   1883 non-null   object
#  6   cap                       1883 non-null   int64
#  7   capChange24h              1883 non-null   int64
#  8   capChangeRatio24H         1883 non-null   float64
#  9   capRank                   1883 non-null   int64
#  10  change24h                 1883 non-null   float64
#  11  changeRatio24H            1883 non-null   float64
#  12  high24h                   1883 non-null   float64
#  13  low24h                    1883 non-null   float64
#  14  price                     1883 non-null   float64
#  15  priceChangePercentage14d  1883 non-null   float64
#  16  priceChangePercentage1H   1883 non-null   float64
#  17  priceChangePercentage1Y   1883 non-null   float64
#  18  priceChangePercentage24H  1883 non-null   float64
#  19  priceChangePercentage30D  1883 non-null   float64
#  20  priceChangePercentage7d   1883 non-null   float64
#  21  supplyCirculating         1883 non-null   float64
#  22  totalVolume               1883 non-null   int64
# dtypes: float64(15), int64(4), object(4)
# memory usage: 338.5+ KB

# %%
df.isnull().sum()
# Out:
# _time                       0
# chainName                   0
# ath                         0
# athDate                     0
# atl                         0
# atlDate                     0
# cap                         0
# capChange24h                0
# capChangeRatio24H           0
# capRank                     0
# change24h                   0
# changeRatio24H              0
# high24h                     0
# low24h                      0
# price                       0
# priceChangePercentage14d    0
# priceChangePercentage1H     0
# priceChangePercentage1Y     0
# priceChangePercentage24H    0
# priceChangePercentage30D    0
# priceChangePercentage7d     0
# supplyCirculating           0
# totalVolume                 0
# dtype: int64

# %%
df.describe()
# Out:
#                 ath           atl            cap  capChange24h  \
# count  1.883000e+03  1.883000e+03    1883.000000   1883.000000
# mean   1.654240e-03  1.429000e-04  149963.850770   -751.260754
# std    2.646156e-17  1.247164e-18   25165.046895   4187.934355
# min    1.654240e-03  1.429000e-04  107634.000000 -14041.000000
# 25%    1.654240e-03  1.429000e-04  119425.500000  -3260.500000
# 50%    1.654240e-03  1.429000e-04  156762.000000   -886.000000
# 75%    1.654240e-03  1.429000e-04  168970.500000   1431.500000
# max    1.654240e-03  1.429000e-04  193924.000000  17368.000000
#
#        capChangeRatio24H      capRank    change24h  changeRatio24H  \
# count        1883.000000  1883.000000  1883.000000     1883.000000
# mean           -0.489688    21.890600    -0.000003       -0.489181
# std             2.740480     0.729471     0.000014        2.736366
# min            -8.793970    20.000000    -0.000046       -8.545310
# 25%            -2.105625    21.000000    -0.000011       -2.096650
# 50%            -0.606720    22.000000    -0.000003       -0.666180
# 75%             0.963735    22.000000     0.000005        0.947585
# max            11.962730    25.000000     0.000058       11.712870
#
#            high24h       low24h        price  priceChangePercentage14d  \
# count  1883.000000  1883.000000  1883.000000               1883.000000
# mean      0.000525     0.000503     0.000513                 -7.286146
# std       0.000087     0.000084     0.000086                  9.686841
# min       0.000376     0.000366     0.000368                -27.251870
# 25%       0.000422     0.000402     0.000408                -12.198720
# 50%       0.000545     0.000526     0.000536                 -7.555175
# 75%       0.000588     0.000568     0.000577                 -3.183195
# max       0.000666     0.000642     0.000661                 20.157488
#
#        priceChangePercentage1H  priceChangePercentage1Y  \
# count              1883.000000              1883.000000
# mean                 -0.015871               -26.513858
# std                   0.554458                11.437006
# min                  -3.330659               -44.438598
# 25%                  -0.286053               -37.210851
# 50%                  -0.043482               -28.147690
# 75%                   0.240628               -16.559026
# max                   4.952716                 1.316571
#
#        priceChangePercentage24H  priceChangePercentage30D  \
# count               1883.000000               1883.000000
# mean                  -0.489181                -11.965880
# std                    2.736366                 12.576756
# min                   -8.545312                -31.727025
# 25%                   -2.096650                -24.689318
# 50%                   -0.666182                -13.256958
# 75%                    0.947587                  0.008380
# max                   11.712872                 10.723631
#
#        priceChangePercentage7d  supplyCirculating   totalVolume
# count              1883.000000       1.883000e+03   1883.000000
# mean                 -3.722590       2.925862e+08   7258.012746
# std                   6.878293       8.466108e-06   2983.973938
# min                 -22.294362       2.925862e+08   2957.000000
# 25%                  -6.834749       2.925862e+08   5045.000000
# 50%                  -3.096135       2.925862e+08   6630.000000
# 75%                   0.108130       2.925862e+08   8699.500000
# max                  14.634393       2.925862e+08  20350.000000

# %%
sns.distplot(df['cap'],kde=True, hist=True)
plt.show()
# Out:
# /var/folders/rz/fqp0nbd52px3k0c93ldtw5fh0000gn/T/ipykernel_33553/3612467878.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cap'],kde=True, hist=True)

# %%
sns.distplot(df['price'],kde=True, hist=True)
plt.show()
# Out:
# /var/folders/rz/fqp0nbd52px3k0c93ldtw5fh0000gn/T/ipykernel_33553/3901859846.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'],kde=True, hist=True)

# %%
sns.distplot(df['totalVolume'],kde=True, hist=True)
plt.show()
# Out:
# /var/folders/rz/fqp0nbd52px3k0c93ldtw5fh0000gn/T/ipykernel_33553/3915431175.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['totalVolume'],kde=True, hist=True)

# %%
sns.distplot(df['priceChangePercentage14d'],kde=True, hist=True)
plt.show()
# Out:
# /var/folders/rz/fqp0nbd52px3k0c93ldtw5fh0000gn/T/ipykernel_33553/3659676493.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['priceChangePercentage14d'],kde=True, hist=True)

# %% [markdown]
# ### 라인차트

# %%
sns.lineplot(x='_time', y = 'cap', data= df)
# Out:
# <Axes: xlabel='_time', ylabel='cap'>

# %%
sns.lineplot(x='_time', y = 'price', data= df)
# Out:
# <Axes: xlabel='_time', ylabel='price'>

# %%
sns.lineplot(x='_time', y = 'totalVolume', data= df)
# Out:
# <Axes: xlabel='_time', ylabel='totalVolume'>

# %%
sns.lineplot(x='_time', y = 'priceChangePercentage14d', data= df)
# Out:
# <Axes: xlabel='_time', ylabel='priceChangePercentage14d'>

# %% [markdown]
# ### 회귀선 + 산점도

# %%
sns.regplot(x='cap', y='totalVolume', data=df)
# Out:
# <Axes: xlabel='cap', ylabel='totalVolume'>

# %%
sns.regplot(x='priceChangePercentage14d', y='totalVolume', data=df)
# Out:
# <Axes: xlabel='priceChangePercentage14d', ylabel='totalVolume'>

# %%
sns.regplot(x='priceChangePercentage14d', y='cap', data=df)
# Out:
# <Axes: xlabel='priceChangePercentage14d', ylabel='cap'>

# %%
df = pd.read_csv(file_path + "/atom-chain-market.csv")
df
# Out:
#                          _time chainName    ath                   athDate  \
# 0     2023-01-22T03:17:05.617Z    cosmos  44.45  2022-01-17T00:34:41.497Z
# 1     2023-01-22T04:00:02.782Z    cosmos  44.45  2022-01-17T00:34:41.497Z
# 2     2023-01-22T05:00:02.824Z    cosmos  44.45  2022-01-17T00:34:41.497Z
# 3     2023-01-22T06:00:03.313Z    cosmos  44.45  2022-01-17T00:34:41.497Z
# 4     2023-01-22T07:00:02.713Z    cosmos  44.45  2022-01-17T00:34:41.497Z
# ...                        ...       ...    ...                       ...
# 1939  2023-04-14T09:59:01.944Z    cosmos  44.45  2022-01-17T00:34:41.497Z
# 1940  2023-04-14T10:59:01.968Z    cosmos  44.45  2022-01-17T00:34:41.497Z
# 1941  2023-04-14T12:00:03.586Z    cosmos  44.45  2022-01-17T00:34:41.497Z
# 1942  2023-04-14T13:00:03.269Z    cosmos  44.45  2022-01-17T00:34:41.497Z
# 1943  2023-04-14T14:00:03.665Z    cosmos  44.45  2022-01-17T00:34:41.497Z
#
#        atl                   atlDate         cap  capChange24h  \
# 0     1.16  2020-03-13T02:27:44.591Z  3859684388     147701676
# 1     1.16  2020-03-13T02:27:44.591Z  3907744616     176277536
# 2     1.16  2020-03-13T02:27:44.591Z  3927643247     184235063
# 3     1.16  2020-03-13T02:27:44.591Z  3937783620     102299572
# 4     1.16  2020-03-13T02:27:44.591Z  3924998829     104038978
# ...    ...                       ...         ...           ...
# 1939  1.16  2020-03-13T02:27:44.591Z  3507681128     205581994
# 1940  1.16  2020-03-13T02:27:44.591Z  3524783794     221736046
# 1941  1.16  2020-03-13T02:27:44.591Z  3498083709     180355505
# 1942  1.16  2020-03-13T02:27:44.591Z  3527540730     213463319
# 1943  1.16  2020-03-13T02:27:44.591Z  3536724239     217247562
#
#       capChangeRatio24H  capRank  ...  low24h  price  \
# 0               3.97905       22  ...   12.71  13.23
# 1               4.72408       22  ...   12.74  13.40
# 2               4.92159       22  ...   12.79  13.40
# 3               2.66719       22  ...   12.93  13.43
# 4               2.72285       22  ...   12.93  13.40
# ...                 ...      ...  ...     ...    ...
# 1939            6.22580       22  ...   11.26  11.97
# 1940            6.71307       22  ...   11.28  12.04
# 1941            5.43611       22  ...   11.32  11.97
# 1942            6.44111       22  ...   11.32  12.06
# 1943            6.54463       22  ...   11.32  12.08
#
#       priceChangePercentage14d  priceChangePercentage1H  \
# 0                    28.957470                -0.485600
# 1                    30.548036                 1.262951
# 2                    30.600500                 0.109195
# 3                    30.878275                -0.008200
# 4                    30.615193                -0.020446
# ...                        ...                      ...
# 1939                  7.445475                 1.296546
# 1940                  8.032595                 0.446129
# 1941                  7.437773                -0.559009
# 1942                  8.265298                 1.067752
# 1943                  8.403717                 0.115702
#
#       priceChangePercentage1Y  priceChangePercentage24H  \
# 0                  -66.135479                  4.076443
# 1                  -65.717793                  5.109553
# 2                  -65.704016                  4.756726
# 3                  -65.631072                  2.355746
# 4                  -65.700158                  2.552304
# ...                       ...                       ...
# 1939               -51.603148                  6.090325
# 1940               -51.338690                  6.467143
# 1941               -51.606617                  5.551262
# 1942               -51.233873                  6.575718
# 1943               -51.171525                  6.458777
#
#       priceChangePercentage30D  priceChangePercentage7d  supplyCirculating  \
# 0                    49.739968                 6.656563        292586163.8
# 1                    51.586867                 7.972070        292586163.8
# 2                    51.647786                 8.015461        292586163.8
# 3                    51.970326                 8.245199        292586163.8
# 4                    51.664846                 8.027613        292586163.8
# ...                        ...                      ...                ...
# 1939                 -8.420835                 5.673736        292586163.8
# 1940                 -7.920415                 6.251174        292586163.8
# 1941                 -8.427400                 5.666161        292586163.8
# 1942                 -7.722075                 6.480040        292586163.8
# 1943                 -7.604096                 6.616177        292586163.8
#
#       totalVolume
# 0       286045792
# 1       270717200
# 2       278476575
# 3       256725694
# 4       248758707
# ...           ...
# 1939    180955819
# 1940    186429847
# 1941    190792631
# 1942    194247513
# 1943    196372459
#
# [1944 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1944 entries, 0 to 1943
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   _time                     1944 non-null   object
#  1   chainName                 1944 non-null   object
#  2   ath                       1944 non-null   float64
#  3   athDate                   1944 non-null   object
#  4   atl                       1944 non-null   float64
#  5   atlDate                   1944 non-null   object
#  6   cap                       1944 non-null   int64
#  7   capChange24h              1944 non-null   int64
#  8   capChangeRatio24H         1944 non-null   float64
#  9   capRank                   1944 non-null   int64
#  10  change24h                 1944 non-null   float64
#  11  changeRatio24H            1944 non-null   float64
#  12  high24h                   1944 non-null   float64
#  13  low24h                    1944 non-null   float64
#  14  price                     1944 non-null   float64
#  15  priceChangePercentage14d  1944 non-null   float64
#  16  priceChangePercentage1H   1944 non-null   float64
#  17  priceChangePercentage1Y   1944 non-null   float64
#  18  priceChangePercentage24H  1944 non-null   float64
#  19  priceChangePercentage30D  1944 non-null   float64
#  20  priceChangePercentage7d   1944 non-null   float64
#  21  supplyCirculating         1944 non-null   float64
#  22  totalVolume               1944 non-null   int64
# dtypes: float64(15), int64(4), object(4)
# memory usage: 349.4+ KB

# %%
df.isnull().sum()
# Out:
# _time                       0
# chainName                   0
# ath                         0
# athDate                     0
# atl                         0
# atlDate                     0
# cap                         0
# capChange24h                0
# capChangeRatio24H           0
# capRank                     0
# change24h                   0
# changeRatio24H              0
# high24h                     0
# low24h                      0
# price                       0
# priceChangePercentage14d    0
# priceChangePercentage1H     0
# priceChangePercentage1Y     0
# priceChangePercentage24H    0
# priceChangePercentage30D    0
# priceChangePercentage7d     0
# supplyCirculating           0
# totalVolume                 0
# dtype: int64

# %%
df.describe()
# Out:
#                 ath           atl           cap  capChange24h  \
# count  1.944000e+03  1.944000e+03  1.944000e+03  1.944000e+03
# mean   4.445000e+01  1.160000e+00  3.678028e+09 -5.263944e+06
# std    1.613347e-12  1.932285e-14  3.562215e+08  1.273541e+08
# min    4.445000e+01  1.160000e+00  3.052012e+09 -4.878811e+08
# 25%    4.445000e+01  1.160000e+00  3.316975e+09 -8.633218e+07
# 50%    4.445000e+01  1.160000e+00  3.683936e+09 -8.589578e+06
# 75%    4.445000e+01  1.160000e+00  3.957845e+09  7.459850e+07
# max    4.445000e+01  1.160000e+00  4.480422e+09  4.906231e+08
#
#        capChangeRatio24H      capRank    change24h  changeRatio24H  \
# count        1944.000000  1944.000000  1944.000000     1944.000000
# mean           -0.080328    21.894547    -0.017831       -0.080075
# std             3.402710     0.722188     0.435496        3.403136
# min           -11.000540    20.000000    -1.680043      -11.158650
# 25%            -2.317157    21.000000    -0.291015       -2.324657
# 50%            -0.230060    22.000000    -0.029098       -0.237650
# 75%             2.073665    22.000000     0.257312        2.083918
# max            12.498890    25.000000     1.740000       13.007880
#
#            high24h       low24h        price  priceChangePercentage14d  \
# count  1944.000000  1944.000000  1944.000000               1944.000000
# mean     12.906322    12.231934    12.570648                 -0.759229
# std       1.262223     1.160629     1.218970                 10.778337
# min      11.000000    10.400000    10.420000                -24.201044
# 25%      11.570000    11.060000    11.337500                 -7.258582
# 50%      13.080000    12.150000    12.600000                 -1.297351
# 75%      13.860000    13.150000    13.522500                  5.206419
# max      15.360000    14.720000    15.240000                 33.550900
#
#        priceChangePercentage1H  priceChangePercentage1Y  \
# count              1944.000000              1944.000000
# mean                 -0.002910               -56.221864
# std                   0.736179                 5.531310
# min                  -5.736206               -66.135479
# 25%                  -0.375434               -60.979172
# 50%                  -0.010349               -56.986907
# 75%                   0.378387               -52.296468
# max                   3.954634               -41.641627
#
#        priceChangePercentage24H  priceChangePercentage30D  \
# count               1944.000000               1944.000000
# mean                  -0.080075                  5.324396
# std                    3.403136                 23.318248
# min                  -11.158649                -30.563239
# 25%                   -2.324656                -12.676782
# 50%                   -0.237653                 -3.644568
# 75%                    2.083917                 20.517971
# max                   13.007878                 57.296847
#
#        priceChangePercentage7d  supplyCirculating   totalVolume
# count              1944.000000       1.944000e+03  1.944000e+03
# mean                 -0.905098       2.925862e+08  1.788599e+08
# std                   8.099661       6.677438e-06  6.605444e+07
# min                 -16.703852       2.925862e+08  6.673950e+07
# 25%                  -7.563867       2.925862e+08  1.292319e+08
# 50%                  -1.064528       2.925862e+08  1.662357e+08
# 75%                   4.234623       2.925862e+08  2.143786e+08
# max                  20.840753       2.925862e+08  4.809314e+08

# %%
sns.distplot(df['cap'],kde=True, hist=True)
plt.show()
# Out:
# /var/folders/rz/fqp0nbd52px3k0c93ldtw5fh0000gn/T/ipykernel_33553/3612467878.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cap'],kde=True, hist=True)

# %%
sns.distplot(df['price'],kde=True, hist=True)
plt.show()
# Out:
# /var/folders/rz/fqp0nbd52px3k0c93ldtw5fh0000gn/T/ipykernel_33553/3901859846.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'],kde=True, hist=True)

# %%
sns.distplot(df['totalVolume'],kde=True, hist=True)
plt.show()
# Out:
# /var/folders/rz/fqp0nbd52px3k0c93ldtw5fh0000gn/T/ipykernel_33553/3915431175.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['totalVolume'],kde=True, hist=True)

# %%
sns.distplot(df['priceChangePercentage7d'],kde=True, hist=True)
plt.show()
# Out:
# /var/folders/rz/fqp0nbd52px3k0c93ldtw5fh0000gn/T/ipykernel_33553/777748535.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['priceChangePercentage7d'],kde=True, hist=True)

# %% [markdown]
# ### 라인차트

# %%
sns.lineplot(x='_time', y = 'cap', data= df)
# Out:
# <Axes: xlabel='_time', ylabel='cap'>

# %%
sns.lineplot(x='_time', y = 'price', data= df)
# Out:
# <Axes: xlabel='_time', ylabel='price'>

# %%
sns.lineplot(x='_time', y = 'totalVolume', data= df)
# Out:
# <Axes: xlabel='_time', ylabel='totalVolume'>

# %%
sns.lineplot(x='_time', y = 'priceChangePercentage7d', data= df)
# Out:
# <Axes: xlabel='_time', ylabel='priceChangePercentage7d'>

# %% [markdown]
# ### 회귀선+산점도

# %%
sns.regplot(x='priceChangePercentage14d', y='cap', data=df)
# Out:
# <Axes: xlabel='priceChangePercentage14d', ylabel='cap'>

# %%
sns.regplot(x='totalVolume', y='cap', data=df)
# Out:
# <Axes: xlabel='totalVolume', ylabel='cap'>

# %%
sns.regplot(x='totalVolume', y='priceChangePercentage14d', data=df)
# Out:
# <Axes: xlabel='totalVolume', ylabel='priceChangePercentage14d'>
