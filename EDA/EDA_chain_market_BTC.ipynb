# %%
import pandas as pd

# %%
file_path = '/Users/yoonjiha/Desktop/파란학기/bluesemesterdata/ver-test2'

# %%
df = pd.read_csv(file_path + "/chain-market-BTC.csv")
df
# Out:
#                          _time chainName       ath                   athDate  \
# 0     2023-01-24T21:00:02.905Z    cosmos  0.001654  2019-03-15T00:00:00.000Z
# 1     2023-01-24T22:00:02.787Z    cosmos  0.001654  2019-03-15T00:00:00.000Z
# 2     2023-01-24T23:00:02.815Z    cosmos  0.001654  2019-03-15T00:00:00.000Z
# 3      2023-01-25T00:00:02.82Z    cosmos  0.001654  2019-03-15T00:00:00.000Z
# 4     2023-01-25T01:00:02.585Z    cosmos  0.001654  2019-03-15T00:00:00.000Z
# ...                        ...       ...       ...                       ...
# 9804  2023-05-08T07:00:03.646Z   osmosis  0.000272  2022-03-04T04:58:42.658Z
# 9805  2023-05-08T08:00:03.493Z   osmosis  0.000272  2022-03-04T04:58:42.658Z
# 9806  2023-05-08T09:00:03.878Z   osmosis  0.000272  2022-03-04T04:58:42.658Z
# 9807  2023-05-08T10:00:03.496Z   osmosis  0.000272  2022-03-04T04:58:42.658Z
# 9808  2023-05-08T11:00:03.377Z   osmosis  0.000272  2022-03-04T04:58:42.658Z
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9809 entries, 0 to 9808
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   _time                     9809 non-null   object
#  1   chainName                 9809 non-null   object
#  2   ath                       9809 non-null   float64
#  3   athDate                   9809 non-null   object
#  4   atl                       9809 non-null   float64
#  5   atlDate                   9809 non-null   object
#  6   cap                       9809 non-null   int64
#  7   capChange24h              9809 non-null   int64
#  8   capChangeRatio24H         9809 non-null   float64
#  9   capRank                   9809 non-null   int64
#  10  change24h                 9809 non-null   float64
#  11  changeRatio24H            9809 non-null   float64
#  12  high24h                   9809 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# _time                       0
# chainName                   0
# ath                         0
# athDate                     0
# atl                         0
# atlDate                     0
# cap                         0
# capChange24h                0
# capChangeRatio24H           0
# capRank                     0
# change24h                   0
# changeRatio24H              0
# high24h                     0
# low24h                      0
# price                       0
# priceChangePercentage14d    0
# priceChangePercentage1H     0
# priceChangePercentage1Y     0
# priceChangePercentage24H    0
# priceChangePercentage30D    0
# priceChangePercentage7d     0
# supplyCirculating           0
# totalVolume                 0
# dtype: int64

# %%
df.describe()
# Out:
#                ath          atl            cap  capChange24h  \
# count  9809.000000  9809.000000    9809.000000   9809.000000
# mean      0.000882     0.000061   44915.806300   -188.941278
# std       0.000550     0.000048   57981.432256   1969.993460
# min       0.000272     0.000021    1582.000000 -14041.000000
# 25%       0.000272     0.000030   12769.000000   -375.000000
# 50%       0.000464     0.000031   15927.000000    -54.000000
# 75%       0.001654     0.000143  108012.000000    145.000000
# max       0.001654     0.000143  193924.000000  17368.000000
#
#        capChangeRatio24H      capRank     change24h  changeRatio24H  \
# count        9809.000000  9809.000000  9.809000e+03     9809.000000
# mean           -0.493071   146.718218 -7.046177e-07       -0.598380
# std             2.875989   129.954335  6.672274e-06        2.859704
# min           -15.505000    20.000000 -4.647580e-05      -15.163760
# 25%            -2.108400    24.000000 -1.270600e-06       -2.208330
# ...

# %%
df.chainName.unique()
# Out:
# array(['cosmos', 'juno', 'kava', 'osmosis'], dtype=object)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x='chainName',data=df)
# Out:
# <Axes: xlabel='chainName', ylabel='count'>

# %% [markdown]
# ### 체인별 cap

# %%
fig, axs = plt.subplots(2,2, figsize=(12,12))
ax1, ax2, ax3, ax4 = axs.flatten()

ax1 = sns.pointplot(x='chainName', y = 'cap', data=df, ax=ax1)
# chainName별 cap 최댓값
ax2 = sns.violinplot(x='chainName', y='cap', data=df, ax=ax2)
ax3 = sns.pointplot(x='chainName', y = 'cap', data=df, estimator=np.max, ax=ax3)
# chainName별 cap 평균값
ax4 = sns.boxplot(x='chainName', y = 'cap', data=df, ax=ax4)

plt.show()

# %% [markdown]
# ### 체인별 price

# %%
fig, axs = plt.subplots(2,2, figsize=(12,12))
ax1, ax2, ax3, ax4 = axs.flatten()

ax1 = sns.pointplot(x='chainName', y = 'price', data=df, ax=ax1)
# chainName별 price 최댓값
ax2 = sns.violinplot(x='chainName', y='price', data=df, ax=ax2)
ax3 = sns.pointplot(x='chainName', y = 'price', data=df, estimator=np.max, ax=ax3)
# chainName별 price 평균값
ax4 = sns.boxplot(x='chainName', y = 'price', data=df, ax=ax4)

plt.show()

# %% [markdown]
# ### 체인별 Volume

# %%
fig, axs = plt.subplots(2,2, figsize=(12,12))
ax1, ax2, ax3, ax4 = axs.flatten()

ax1 = sns.pointplot(x='chainName', y = 'totalVolume', data=df, ax=ax1)
# chainName별 totalVolume 최댓값
ax2 = sns.violinplot(x='chainName', y='totalVolume', data=df, ax=ax2)
ax3 = sns.pointplot(x='chainName', y = 'totalVolume', data=df, estimator=np.max, ax=ax3)
# chainName별 totalVolume 평균값
ax4 = sns.boxplot(x='chainName', y = 'totalVolume', data=df, ax=ax4)

plt.show()

# %% [markdown]
# ### 체인별 14일 단위 가격 변화율

# %%
fig, axs = plt.subplots(2,2, figsize=(12,12))
ax1, ax2, ax3, ax4 = axs.flatten()

ax1 = sns.pointplot(x='chainName', y = 'priceChangePercentage14d', data=df, ax=ax1)
# chainName별 totalVolume 최댓값
ax2 = sns.violinplot(x='chainName', y='priceChangePercentage14d', data=df, ax=ax2)
ax3 = sns.pointplot(x='chainName', y = 'priceChangePercentage14d', data=df, estimator=np.max, ax=ax3)
# chainName별 totalVolume 평균값
ax4 = sns.boxplot(x='chainName', y = 'priceChangePercentage14d', data=df, ax=ax4)

plt.show()

# %%
cos_df = pd.DataFrame()
juno_df = pd.DataFrame()
kava_df = pd.DataFrame()
osmo_df = pd.DataFrame()

# %%
cos_df = df[df['chainName']=='cosmos']
juno_df = df[df['chainName']=='juno']
kava_df = df[df['chainName']=='kava']
osmo_df = df[df['chainName']=='osmosis']

cos_df
# Out:
#                          _time chainName       ath                   athDate  \
# 0     2023-01-24T21:00:02.905Z    cosmos  0.001654  2019-03-15T00:00:00.000Z
# 1     2023-01-24T22:00:02.787Z    cosmos  0.001654  2019-03-15T00:00:00.000Z
# 2     2023-01-24T23:00:02.815Z    cosmos  0.001654  2019-03-15T00:00:00.000Z
# 3      2023-01-25T00:00:02.82Z    cosmos  0.001654  2019-03-15T00:00:00.000Z
# 4     2023-01-25T01:00:02.585Z    cosmos  0.001654  2019-03-15T00:00:00.000Z
# ...                        ...       ...       ...                       ...
# 2450  2023-05-08T07:00:03.607Z    cosmos  0.001654  2019-03-15T00:00:00.000Z
# 2451  2023-05-08T08:00:03.478Z    cosmos  0.001654  2019-03-15T00:00:00.000Z
# 2452  2023-05-08T09:00:03.849Z    cosmos  0.001654  2019-03-15T00:00:00.000Z
# 2453   2023-05-08T10:00:03.45Z    cosmos  0.001654  2019-03-15T00:00:00.000Z
# 2454  2023-05-08T11:00:03.355Z    cosmos  0.001654  2019-03-15T00:00:00.000Z
#
# ...

# %% [markdown]
# ## 확률밀도함수+히스토그램

# %% [markdown]
# ### 코인별 cap 분포

# %%
fig, axs = plt.subplots(2,2, figsize=(10,10))
ax1, ax2, ax3, ax4 = axs.flatten()

ax1 = sns.distplot(cos_df['cap'],kde=True, hist=True, ax=ax1)
ax2 = sns.distplot(juno_df['cap'],kde=True, hist=True, ax=ax2)
ax3 = sns.distplot(kava_df['cap'],kde=True, hist=True, ax=ax3)
ax4 = sns.distplot(osmo_df['cap'],kde=True, hist=True, ax=ax4)

ax1.set_title('<Distplot of cap from cosmos>')
ax2.set_title('<Distplot of cap from juno>')
ax3.set_title('<Distplot of cap kava>')
ax4.set_title('<Distplot of cap osmosis>')

plt.show()
# Out:
# /var/folders/rz/fqp0nbd52px3k0c93ldtw5fh0000gn/T/ipykernel_3046/440789702.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(cos_df['cap'],kde=True, hist=True, ax=ax1)
# /var/folders/rz/fqp0nbd52px3k0c93ldtw5fh0000gn/T/ipykernel_3046/440789702.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# ### 코인별 price 분포

# %%
fig, axs = plt.subplots(2,2, figsize=(10,10))
ax1, ax2, ax3, ax4 = axs.flatten()

ax1 = sns.distplot(cos_df['price'],kde=True, hist=True, ax=ax1)
ax2 = sns.distplot(juno_df['price'],kde=True, hist=True, ax=ax2)
ax3 = sns.distplot(kava_df['price'],kde=True, hist=True, ax=ax3)
ax4 = sns.distplot(osmo_df['price'],kde=True, hist=True, ax=ax4)

ax1.set_title('<Distplot of price from cosmos>')
ax2.set_title('<Distplot of price from juno>')
ax3.set_title('<Distplot of price kava>')
ax4.set_title('<Distplot of price osmosis>')

plt.show()
# Out:
# /var/folders/rz/fqp0nbd52px3k0c93ldtw5fh0000gn/T/ipykernel_3046/2710057998.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(cos_df['price'],kde=True, hist=True, ax=ax1)
# /var/folders/rz/fqp0nbd52px3k0c93ldtw5fh0000gn/T/ipykernel_3046/2710057998.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# ### 코인별 total Volume 분포

# %%
fig, axs = plt.subplots(2,2, figsize=(10,10))
ax1, ax2, ax3, ax4 = axs.flatten()

ax1 = sns.distplot(cos_df['totalVolume'],kde=True, hist=True, ax=ax1)
ax2 = sns.distplot(juno_df['totalVolume'],kde=True, hist=True, ax=ax2)
ax3 = sns.distplot(kava_df['totalVolume'],kde=True, hist=True, ax=ax3)
ax4 = sns.distplot(osmo_df['totalVolume'],kde=True, hist=True, ax=ax4)

ax1.set_title('<Distplot of totalVolume from cosmos>')
ax2.set_title('<Distplot of totalVolume from juno>')
ax3.set_title('<Distplot of totalVolume kava>')
ax4.set_title('<Distplot of totalVolume osmosis>')

plt.show()
# Out:
# /var/folders/rz/fqp0nbd52px3k0c93ldtw5fh0000gn/T/ipykernel_3046/935880769.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(cos_df['totalVolume'],kde=True, hist=True, ax=ax1)
# /var/folders/rz/fqp0nbd52px3k0c93ldtw5fh0000gn/T/ipykernel_3046/935880769.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# ### 코인별 14일 단위 가격변화율 분포

# %%
fig, axs = plt.subplots(2,2, figsize=(10,10))
ax1, ax2, ax3, ax4 = axs.flatten()

ax1 = sns.distplot(cos_df['priceChangePercentage14d'],kde=True, hist=True, ax=ax1)
ax2 = sns.distplot(juno_df['priceChangePercentage14d'],kde=True, hist=True, ax=ax2)
ax3 = sns.distplot(kava_df['priceChangePercentage14d'],kde=True, hist=True, ax=ax3)
ax4 = sns.distplot(osmo_df['priceChangePercentage14d'],kde=True, hist=True, ax=ax4)

ax1.set_title('<priceChangePercentage14d from cosmos>')
ax2.set_title('<priceChangePercentage14d from juno>')
ax3.set_title('<priceChangePercentage14d kava>')
ax4.set_title('<priceChangePercentage14d osmosis>')

plt.show()
# Out:
# /var/folders/rz/fqp0nbd52px3k0c93ldtw5fh0000gn/T/ipykernel_3046/2322448832.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(cos_df['priceChangePercentage14d'],kde=True, hist=True, ax=ax1)
# /var/folders/rz/fqp0nbd52px3k0c93ldtw5fh0000gn/T/ipykernel_3046/2322448832.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# ## 라인차트

# %% [markdown]
# ### 코인별 시간에 따른 cap 변화

# %%
fig, axs = plt.subplots(2,2, figsize=(10,10))
ax1, ax2, ax3, ax4 = axs.flatten()

ax1 = sns.lineplot(x='_time', y = 'cap', data= cos_df, ax=ax1)
ax2 = sns.lineplot(x='_time', y = 'cap', data= juno_df, ax=ax2)
ax3 = sns.lineplot(x='_time', y = 'cap', data= kava_df, ax=ax3)
ax4 = sns.lineplot(x='_time', y = 'cap', data= osmo_df, ax=ax4)

ax1.set_title('<cap linechart from cosmos>')
ax2.set_title('<cap linechart from juno>')
ax3.set_title('<cap linechart from kava>')
ax4.set_title('<cap linechart from osmosis>')

plt.show()

# %% [markdown]
# ### 코인별 시간에 따른 price 변화

# %%
fig, axs = plt.subplots(2,2, figsize=(10,10))
ax1, ax2, ax3, ax4 = axs.flatten()

ax1 = sns.lineplot(x='_time', y = 'price', data= cos_df, ax=ax1)
ax2 = sns.lineplot(x='_time', y = 'price', data= juno_df, ax=ax2)
ax3 = sns.lineplot(x='_time', y = 'price', data= kava_df, ax=ax3)
ax4 = sns.lineplot(x='_time', y = 'price', data= osmo_df, ax=ax4)

ax1.set_title('<price linechart from cosmos>')
ax2.set_title('<price linechart from juno>')
ax3.set_title('<price linechart from kava>')
ax4.set_title('<price linechart from osmosis>')

plt.show()

# %% [markdown]
# ### 코인별 시간에 따른 Volume 변화

# %%
fig, axs = plt.subplots(2,2, figsize=(10,10))
ax1, ax2, ax3, ax4 = axs.flatten()

ax1 = sns.lineplot(x='_time', y = 'totalVolume', data= cos_df, ax=ax1)
ax2 = sns.lineplot(x='_time', y = 'totalVolume', data= juno_df, ax=ax2)
ax3 = sns.lineplot(x='_time', y = 'totalVolume', data= kava_df, ax=ax3)
ax4 = sns.lineplot(x='_time', y = 'totalVolume', data= osmo_df, ax=ax4)

ax1.set_title('<Volume linechart from cosmos>')
ax2.set_title('<Volume linechart from juno>')
ax3.set_title('<Volume linechart from kava>')
ax4.set_title('<Volume linechart from osmosis>')

plt.show()

# %% [markdown]
# ### 코인별 시간에 따른 14일 단위 가격 변화율

# %%
fig, axs = plt.subplots(2,2, figsize=(10,10))
ax1, ax2, ax3, ax4 = axs.flatten()

ax1 = sns.lineplot(x='_time', y = 'priceChangePercentage14d', data= cos_df, ax=ax1)
ax2 = sns.lineplot(x='_time', y = 'priceChangePercentage14d', data= juno_df, ax=ax2)
ax3 = sns.lineplot(x='_time', y = 'priceChangePercentage14d', data= kava_df, ax=ax3)
ax4 = sns.lineplot(x='_time', y = 'priceChangePercentage14d', data= osmo_df, ax=ax4)

ax1.set_title('<priceChangePercentage14d from cosmos>')
ax2.set_title('<priceChangePercentage14d from juno>')
ax3.set_title('<priceChangePercentage14d from kava>')
ax4.set_title('<priceChangePercentage14d from osmosis>')

plt.show()

# %% [markdown]
# ## 회귀선 + 산점도

# %% [markdown]
# ### 코인별 cap과 Volume 상관관계

# %%
fig, axs = plt.subplots(2,2, figsize=(10,10))
ax1, ax2, ax3, ax4 = axs.flatten()

ax1 = sns.regplot(x='cap', y='totalVolume', data=cos_df, ax=ax1)
ax2 = sns.regplot(x='cap', y='totalVolume', data=juno_df, ax=ax2)
ax3 = sns.regplot(x='cap', y='totalVolume', data=kava_df, ax=ax3)
ax4 = sns.regplot(x='cap', y='totalVolume', data=osmo_df, ax=ax4)

ax1.set_title('<Scatterplot of cap&Volume from cosmos>')
ax2.set_title('<Scatterplot of cap&Volume from juno>')
ax3.set_title('<Scatterplot of cap&Volume from kava>')
ax4.set_title('<Scatterplot of cap&Volume from osmosis>')

plt.show()

# %% [markdown]
# ### 코인별 14일 단위 가격변화율과 volume 상관관계

# %%
fig, axs = plt.subplots(2,2, figsize=(10,10))
ax1, ax2, ax3, ax4 = axs.flatten()

ax1 = sns.regplot(x='priceChangePercentage14d', y='totalVolume', data=cos_df, ax=ax1)
ax2 = sns.regplot(x='priceChangePercentage14d', y='totalVolume', data=juno_df, ax=ax2)
ax3 = sns.regplot(x='priceChangePercentage14d', y='totalVolume', data=kava_df, ax=ax3)
ax4 = sns.regplot(x='priceChangePercentage14d', y='totalVolume', data=osmo_df, ax=ax4)

ax1.set_title('<Scatterplot of price(14d)&Volume from cosmos>')
ax2.set_title('<Scatterplot of price(14d)&Volume from juno>')
ax3.set_title('<Scatterplot of price(14d)&Volume from kava>')
ax4.set_title('<Scatterplot of price(14d)&Volume from osmosis>')

plt.show()

# %% [markdown]
# ### 코인별 14일 단위 가격변화율과 cap 상관관계

# %%
fig, axs = plt.subplots(2,2, figsize=(10,10))
ax1, ax2, ax3, ax4 = axs.flatten()

ax1 = sns.regplot(x='priceChangePercentage14d', y='cap', data=cos_df, ax=ax1)
ax2 = sns.regplot(x='priceChangePercentage14d', y='cap', data=juno_df, ax=ax2)
ax3 = sns.regplot(x='priceChangePercentage14d', y='cap', data=kava_df, ax=ax3)
ax4 = sns.regplot(x='priceChangePercentage14d', y='cap', data=osmo_df, ax=ax4)

ax1.set_title('<Scatterplot of price(14d)&cap from cosmos>')
ax2.set_title('<Scatterplot of price(14d)&cap from juno>')
ax3.set_title('<Scatterplot of price(14d)&cap from kava>')
ax4.set_title('<Scatterplot of price(14d)&cap from osmosis>')

plt.show()

# %% [markdown]
# ### 코인별 14일 단위 가격변화율과 price 상관관계

# %%
fig, axs = plt.subplots(2,2, figsize=(12,12))
ax1, ax2, ax3, ax4 = axs.flatten()

ax1 = sns.regplot(x='priceChangePercentage14d', y='price', data=cos_df, ax=ax1)
ax2 = sns.regplot(x='priceChangePercentage14d', y='price', data=juno_df, ax=ax2)
ax3 = sns.regplot(x='priceChangePercentage14d', y='price', data=kava_df, ax=ax3)
ax4 = sns.regplot(x='priceChangePercentage14d', y='price', data=osmo_df, ax=ax4)

ax1.set_title('<Scatterplot of price(14d)&price from cosmos>')
ax2.set_title('<Scatterplot of price(14d)&price from juno>')
ax3.set_title('<Scatterplot of price(14d)&price from kava>')
ax4.set_title('<Scatterplot of price(14d)&price from osmosis>')

plt.show()
