# %%
import numpy as np
import pandas as pd
import seaborn as sns
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, LSTM, GRU, Dropout
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MaxAbsScaler

# Read data
df = pd.read_csv('data.csv')
# 쓸데없는 index 제거
df = df.drop(df.columns[0], axis=1)
#print(df.head())

train_hours = pd.to_datetime(df['_time'])
#print(train_hours.tail(15))

# moduleName = cosmos만 고르기
cosmos_df = df[df['chainName'] == "cosmos"]
columns_to_keep = ['_time', 'price', 'DokiaCapital #02 (Validator)-amountValue', 'DokiaCapital #01 (Validator)-amountValue']
cosmos_df = cosmos_df[columns_to_keep]
print(cosmos_df.shape)
# (2446, 5)
# Out:
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# (2446, 4)

# %%
# Plot 'price' over '_time'
plt.figure(figsize=(15, 6))
plt.plot_date(cosmos_df['_time'], cosmos_df['price'], linestyle='solid', marker=None)
plt.title('Price over time')
plt.xlabel('Time')
plt.ylabel('Price')
plt.show()
# Out:
# /var/folders/rs/451vhmx909jbf4784zj52l980000gn/T/ipykernel_50594/863480140.py:3: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot_date(cosmos_df['_time'], cosmos_df['price'], linestyle='solid', marker=None)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[67], line 7
#       5 plt.xlabel('Time')
#       6 plt.ylabel('Price')
# ----> 7 plt.show()
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
#     445 _warn_if_gui_out_of_main_thread()
# --> 446 return _get_backend_mod().show(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:43, in show(close, block)
#      39 try:
#      40     for figure_manager in Gcf.get_all_fig_managers():
#      41         display(
#      42             figure_manager.canvas.figure,
# ---> 43             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44         )
#      45 finally:
#      46     show._to_draw = []
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:231, in _fetch_figure_metadata(fig)
#     228 # determine if a background is needed for legibility
#     229 if _is_transparent(fig.get_facecolor()):
#     230     # the background is transparent
# --> 231     ticksLight = _is_light([label.get_color()
#     232                             for axes in fig.axes
#     233                             for axis in (axes.xaxis, axes.yaxis)
#     234                             for label in axis.get_ticklabels()])
#     235     if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     236         # there are one or more tick labels, all with the same lightness
#     237         return {'needs_background': 'dark' if ticksLight[0] else 'light'}
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:234, in <listcomp>(.0)
#     228 # determine if a background is needed for legibility
#     229 if _is_transparent(fig.get_facecolor()):
#     230     # the background is transparent
#     231     ticksLight = _is_light([label.get_color()
#     232                             for axes in fig.axes
#     233                             for axis in (axes.xaxis, axes.yaxis)
# --> 234                             for label in axis.get_ticklabels()])
#     235     if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     236         # there are one or more tick labels, all with the same lightness
#     237         return {'needs_background': 'dark' if ticksLight[0] else 'light'}
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py:1456, in Axis.get_ticklabels(self, minor, which)
#    1454 if minor:
#    1455     return self.get_minorticklabels()
# -> 1456 return self.get_majorticklabels()
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py:1413, in Axis.get_majorticklabels(self)
#    1411 def get_majorticklabels(self):
#    1412     """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1413     self._update_ticks()
#    1414     ticks = self.get_major_ticks()
#    1415     labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py:1264, in Axis._update_ticks(self)
#    1262 major_locs = self.get_majorticklocs()
#    1263 major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1264 major_ticks = self.get_major_ticks(len(major_locs))
#    1265 self.major.formatter.set_locs(major_locs)
#    1266 for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py:1602, in Axis.get_major_ticks(self, numticks)
#    1598     numticks = len(self.get_majorticklocs())
#    1600 while len(self.majorTicks) < numticks:
#    1601     # Update the new tick label properties from the old.
# -> 1602     tick = self._get_tick(major=True)
#    1603     self.majorTicks.append(tick)
#    1604     self._copy_tick_props(self.majorTicks[0], tick)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py:1551, in Axis._get_tick(self, major)
#    1547     raise NotImplementedError(
#    1548         f"The Axis subclass {self.__class__.__name__} must define "
#    1549         "_tick_class or reimplement _get_tick()")
#    1550 tick_kw = self._major_tick_kw if major else self._minor_tick_kw
# -> 1551 return self._tick_class(self.axes, 0, major=major, **tick_kw)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py:417, in XTick.__init__(self, *args, **kwargs)
#     416 def __init__(self, *args, **kwargs):
# --> 417     super().__init__(*args, **kwargs)
#     418     # x in data coords, y in axes coords
#     419     ax = self.axes
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py:166, in Tick.__init__(self, axes, loc, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kwargs)
#     156 self.tick1line = mlines.Line2D(
#     157     [], [],
#     158     color=color, linestyle="none", zorder=zorder, visible=tick1On,
#     159     markeredgecolor=color, markersize=size, markeredgewidth=width,
#     160 )
#     161 self.tick2line = mlines.Line2D(
#     162     [], [],
#     163     color=color, linestyle="none", zorder=zorder, visible=tick2On,
#     164     markeredgecolor=color, markersize=size, markeredgewidth=width,
#     165 )
# --> 166 self.gridline = mlines.Line2D(
#     167     [], [],
#     168     color=grid_color, alpha=grid_alpha, visible=gridOn,
#     169     linestyle=grid_linestyle, linewidth=grid_linewidth, marker="",
#     170     **grid_kw,
#     171 )
#     172 self.gridline.get_path()._interpolation_steps = \
#     173     GRIDLINE_INTERPOLATION_STEPS
#     174 self.label1 = mtext.Text(
#     175     np.nan, np.nan,
#     176     fontsize=labelsize, color=labelcolor, visible=label1On,
#     177     rotation=self._labelrotation[1])
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/matplotlib/lines.py:362, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     359 self.set_drawstyle(drawstyle)
#     361 self._color = None
# --> 362 self.set_color(color)
#     363 if marker is None:
#     364     marker = 'none'  # Default.
#
# KeyboardInterrupt:

# %%
# data normalizing
cols = list(cosmos_df)[1:cosmos_df.shape[1]]
print(cols)
print(cosmos_df.shape)
#(2446, 5)

df_for_training = cosmos_df[cols].astype(float)
print(df_for_training.shape)
#(2446, 4)

scaler = MaxAbsScaler()
scaler.fit(df_for_training)
df_for_training_scaled = scaler.transform(df_for_training)
print(df_for_training_scaled.shape)
#(2446, 4)
# Out:
# ['price', 'DokiaCapital #02 (Validator)-amountValue', 'DokiaCapital #01 (Validator)-amountValue']
# (2446, 4)
# (2446, 3)
# (2446, 3)

# %%
trainX = []
trainY = []

n_future = 1
n_past = 24 # 24시간

for i in range(n_past, len(df_for_training_scaled) - n_future + 1):
    trainX.append(df_for_training_scaled[i - n_past:i, 0:df_for_training_scaled.shape[1]])
    trainY.append(df_for_training_scaled[i + n_future - 1:i + n_future, 0])
    
trainX, trainY = np.array(trainX), np.array(trainY)

print('trainX shape == {}.'.format(trainX.shape))
# (2422, 24, 4)
print('trainY shape == {}.'.format(trainY.shape))
# (2422, 1)
# ...
# Out:
# trainX shape == (2422, 24, 3).
# trainY shape == (2422, 1).

# %%
## 여기 shape 수정해야될 거 같은데.
model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(trainY.shape[1]))

model.compile(optimizer='adam', loss='mse')
model.summary()

# fit the model
history = model.fit(trainX, trainY, epochs=101, batch_size=24, validation_split=0.2, verbose=1)

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()

# save the model to disk
model.save('./models/my_model-6-2')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 24, 64)            17408
#
#  dropout (Dropout)           (None, 24, 64)            0
#
#  lstm_1 (LSTM)               (None, 32)                12416
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 29857 (116.63 KB)
# Trainable params: 29857 (116.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/101
# 81/81 [==============================] - 2s 14ms/step - loss: 0.1134 - val_loss: 3.2761e-04
# Epoch 2/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0192 - val_loss: 0.0011
# Epoch 3/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0155 - val_loss: 3.3975e-04
# Epoch 4/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0148 - val_loss: 3.0308e-04
# Epoch 5/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0131 - val_loss: 3.4741e-04
# Epoch 6/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0126 - val_loss: 6.4117e-04
# Epoch 7/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0115 - val_loss: 2.4892e-04
# Epoch 8/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0114 - val_loss: 2.1418e-04
# Epoch 9/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0109 - val_loss: 2.9730e-04
# Epoch 10/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0100 - val_loss: 2.3370e-04
# Epoch 11/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0102 - val_loss: 2.8718e-04
# Epoch 12/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0094 - val_loss: 2.5997e-04
# Epoch 13/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0092 - val_loss: 2.7798e-04
# Epoch 14/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0081 - val_loss: 2.5507e-04
# Epoch 15/101
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0079 - val_loss: 4.7714e-04
# Epoch 16/101
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0074 - val_loss: 2.4274e-04
# Epoch 17/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0075 - val_loss: 2.3314e-04
# Epoch 18/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0069 - val_loss: 7.3024e-04
# Epoch 19/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0066 - val_loss: 3.0854e-04
# Epoch 20/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0063 - val_loss: 3.7013e-04
# Epoch 21/101
# 81/81 [==============================] - 1s 15ms/step - loss: 0.0058 - val_loss: 6.1672e-04
# Epoch 22/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0055 - val_loss: 2.2780e-04
# Epoch 23/101
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0052 - val_loss: 1.9663e-04
# Epoch 24/101
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0048 - val_loss: 9.5883e-04
# Epoch 25/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0047 - val_loss: 8.6672e-04
# Epoch 26/101
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0043 - val_loss: 4.7126e-04
# Epoch 27/101
# 81/81 [==============================] - 1s 15ms/step - loss: 0.0043 - val_loss: 2.0331e-04
# Epoch 28/101
# 81/81 [==============================] - 1s 16ms/step - loss: 0.0041 - val_loss: 1.8683e-04
# Epoch 29/101
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0037 - val_loss: 1.8948e-04
# Epoch 30/101
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0037 - val_loss: 3.7804e-04
# Epoch 31/101
# 81/81 [==============================] - 1s 15ms/step - loss: 0.0031 - val_loss: 2.2197e-04
# Epoch 32/101
# 81/81 [==============================] - 1s 15ms/step - loss: 0.0030 - val_loss: 2.2414e-04
# Epoch 33/101
# 81/81 [==============================] - 2s 22ms/step - loss: 0.0030 - val_loss: 5.7458e-04
# Epoch 34/101
# 81/81 [==============================] - 1s 16ms/step - loss: 0.0029 - val_loss: 2.2700e-04
# Epoch 35/101
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0025 - val_loss: 7.1931e-04
# Epoch 36/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0024 - val_loss: 0.0011
# Epoch 37/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0023 - val_loss: 6.7269e-04
# Epoch 38/101
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0022 - val_loss: 6.8555e-04
# Epoch 39/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0019 - val_loss: 3.9904e-04
# Epoch 40/101
# 81/81 [==============================] - 1s 16ms/step - loss: 0.0018 - val_loss: 4.1413e-04
# Epoch 41/101
# 81/81 [==============================] - 2s 26ms/step - loss: 0.0017 - val_loss: 2.0283e-04
# Epoch 42/101
# 81/81 [==============================] - 2s 25ms/step - loss: 0.0016 - val_loss: 1.7634e-04
# Epoch 43/101
# 81/81 [==============================] - 2s 22ms/step - loss: 0.0014 - val_loss: 2.1642e-04
# Epoch 44/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0013 - val_loss: 1.6823e-04
# Epoch 45/101
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0013 - val_loss: 4.1109e-04
# Epoch 46/101
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0012 - val_loss: 2.7351e-04
# Epoch 47/101
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0011 - val_loss: 4.1060e-04
# Epoch 48/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0011 - val_loss: 1.9513e-04
# Epoch 49/101
# 81/81 [==============================] - 1s 13ms/step - loss: 9.7232e-04 - val_loss: 4.0160e-04
# Epoch 50/101
# 81/81 [==============================] - 1s 14ms/step - loss: 9.3081e-04 - val_loss: 7.7321e-04
# Epoch 51/101
# 81/81 [==============================] - 1s 16ms/step - loss: 8.8170e-04 - val_loss: 5.6176e-04
# Epoch 52/101
# 81/81 [==============================] - 1s 14ms/step - loss: 7.8479e-04 - val_loss: 2.5255e-04
# Epoch 53/101
# 81/81 [==============================] - 1s 14ms/step - loss: 8.3282e-04 - val_loss: 3.0596e-04
# Epoch 54/101
# 81/81 [==============================] - 1s 13ms/step - loss: 7.1524e-04 - val_loss: 8.9084e-04
# Epoch 55/101
# 81/81 [==============================] - 1s 13ms/step - loss: 6.7313e-04 - val_loss: 3.7644e-04
# Epoch 56/101
# 81/81 [==============================] - 1s 13ms/step - loss: 6.1991e-04 - val_loss: 3.3291e-04
# Epoch 57/101
# 81/81 [==============================] - 1s 13ms/step - loss: 5.8450e-04 - val_loss: 5.2218e-04
# Epoch 58/101
# 81/81 [==============================] - 1s 14ms/step - loss: 5.4360e-04 - val_loss: 4.8632e-04
# Epoch 59/101
# 81/81 [==============================] - 1s 15ms/step - loss: 5.8351e-04 - val_loss: 5.3293e-04
# Epoch 60/101
# 81/81 [==============================] - 1s 13ms/step - loss: 5.3947e-04 - val_loss: 5.0332e-04
# Epoch 61/101
# 81/81 [==============================] - 1s 13ms/step - loss: 5.2587e-04 - val_loss: 5.8701e-04
# Epoch 62/101
# 81/81 [==============================] - 1s 13ms/step - loss: 4.7620e-04 - val_loss: 3.6924e-04
# Epoch 63/101
# 81/81 [==============================] - 1s 13ms/step - loss: 4.3501e-04 - val_loss: 2.4603e-04
# Epoch 64/101
# 81/81 [==============================] - 1s 13ms/step - loss: 5.0752e-04 - val_loss: 2.9343e-04
# Epoch 65/101
# 81/81 [==============================] - 1s 13ms/step - loss: 4.8985e-04 - val_loss: 9.6255e-04
# Epoch 66/101
# 81/81 [==============================] - 1s 15ms/step - loss: 4.2771e-04 - val_loss: 3.5078e-04
# Epoch 67/101
# 81/81 [==============================] - 1s 13ms/step - loss: 4.3772e-04 - val_loss: 7.9836e-04
# Epoch 68/101
# 81/81 [==============================] - 1s 14ms/step - loss: 4.4172e-04 - val_loss: 7.2924e-04
# Epoch 69/101
# 81/81 [==============================] - 1s 13ms/step - loss: 4.4625e-04 - val_loss: 5.2925e-04
# Epoch 70/101
# 81/81 [==============================] - 1s 13ms/step - loss: 4.2613e-04 - val_loss: 5.7448e-04
# Epoch 71/101
# 81/81 [==============================] - 1s 13ms/step - loss: 4.2892e-04 - val_loss: 8.5716e-04
# Epoch 72/101
# 81/81 [==============================] - 1s 13ms/step - loss: 4.1295e-04 - val_loss: 3.5052e-04
# Epoch 73/101
# 81/81 [==============================] - 1s 13ms/step - loss: 4.1711e-04 - val_loss: 3.7596e-04
# Epoch 74/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.8919e-04 - val_loss: 4.0258e-04
# Epoch 75/101
# 81/81 [==============================] - 1s 14ms/step - loss: 4.0299e-04 - val_loss: 5.9917e-04
# Epoch 76/101
# 81/81 [==============================] - 1s 14ms/step - loss: 3.6843e-04 - val_loss: 4.7668e-04
# Epoch 77/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.8937e-04 - val_loss: 7.2808e-04
# Epoch 78/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.8767e-04 - val_loss: 2.2084e-04
# Epoch 79/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.6157e-04 - val_loss: 3.8392e-04
# Epoch 80/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.5408e-04 - val_loss: 4.6656e-04
# Epoch 81/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.6876e-04 - val_loss: 3.3975e-04
# Epoch 82/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.4774e-04 - val_loss: 3.1257e-04
# Epoch 83/101
# 81/81 [==============================] - 1s 15ms/step - loss: 3.5843e-04 - val_loss: 4.6604e-04
# Epoch 84/101
# 81/81 [==============================] - 1s 14ms/step - loss: 3.6725e-04 - val_loss: 5.0987e-04
# Epoch 85/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.5182e-04 - val_loss: 2.7972e-04
# Epoch 86/101
# 81/81 [==============================] - 1s 14ms/step - loss: 3.1582e-04 - val_loss: 5.7924e-04
# Epoch 87/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.5078e-04 - val_loss: 3.6545e-04
# Epoch 88/101
# 81/81 [==============================] - 2s 30ms/step - loss: 3.5309e-04 - val_loss: 6.5761e-04
# Epoch 89/101
# 81/81 [==============================] - 2s 22ms/step - loss: 3.4641e-04 - val_loss: 3.5988e-04
# Epoch 90/101
# 81/81 [==============================] - 1s 14ms/step - loss: 3.5485e-04 - val_loss: 5.1668e-04
# Epoch 91/101
# 81/81 [==============================] - 2s 28ms/step - loss: 3.3694e-04 - val_loss: 4.2904e-04
# Epoch 92/101
# 81/81 [==============================] - 2s 20ms/step - loss: 3.2364e-04 - val_loss: 4.7472e-04
# Epoch 93/101
# 81/81 [==============================] - 2s 20ms/step - loss: 3.3275e-04 - val_loss: 5.1103e-04
# Epoch 94/101
# 81/81 [==============================] - 1s 18ms/step - loss: 3.4242e-04 - val_loss: 3.4407e-04
# Epoch 95/101
# 81/81 [==============================] - 1s 14ms/step - loss: 3.2072e-04 - val_loss: 2.9288e-04
# Epoch 96/101
# 81/81 [==============================] - 1s 16ms/step - loss: 3.1632e-04 - val_loss: 1.7937e-04
# Epoch 97/101
# 81/81 [==============================] - 1s 14ms/step - loss: 3.5675e-04 - val_loss: 4.7379e-04
# Epoch 98/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.2825e-04 - val_loss: 6.1192e-04
# Epoch 99/101
# 81/81 [==============================] - 1s 15ms/step - loss: 3.0797e-04 - val_loss: 4.9062e-04
# Epoch 100/101
# 81/81 [==============================] - 1s 14ms/step - loss: 3.5298e-04 - val_loss: 5.3498e-04
# Epoch 101/101
# 81/81 [==============================] - 1s 14ms/step - loss: 3.3998e-04 - val_loss: 3.6765e-04
# INFO:tensorflow:Assets written to: ./models/my_model-6-2/assets
# INFO:tensorflow:Assets written to: ./models/my_model-6-2/assets

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# load the model from disk
model = load_model('./models/my_model-6-2')

def evaluate_model(model, X, y_true, scaler, df_for_training):
    # Predict
    y_pred = model.predict(X)
    
    # Create dummy arrays for inverse transform
    dummy_pred = np.zeros((len(y_pred), df_for_training.shape[1]))
    dummy_true = np.zeros((len(y_true), df_for_training.shape[1]))
    
    # Replace the first column with predicted and actual values
    dummy_pred[:,0] = y_pred[:,0]
    dummy_true[:,0] = y_true[:,0]
    
    # Inverse transform
    y_pred_rescaled = scaler.inverse_transform(dummy_pred)[:,0]
    y_true_rescaled = scaler.inverse_transform(dummy_true)[:,0]
    
    # Calculate RMSE
    rmse = sqrt(mean_squared_error(y_true_rescaled, y_pred_rescaled))
    
    # Plot actual vs predicted values
    plt.figure(figsize=(15, 6))
    plt.plot(y_true_rescaled, label='Actual')
    plt.plot(y_pred_rescaled, label='Predicted')
    plt.title('Actual vs Predicted')
    plt.ylabel('Price')
    plt.legend()
    plt.show()
    
    return rmse

# Call the function
trainScore = evaluate_model(model, trainX, trainY, scaler, df_for_training)
print('Train Score: %.2f RMSE' % (trainScore))

# If you also have a test dataset, you can do:
# testPredict = model.predict(testX)
# testPredict = scaler.inverse_transform(testPredict)
# testY_true = scaler.inverse_transform(testY)
# testScore = sqrt(mean_squared_error(testY_true, testPredict))
# print('Test Score: %.2f RMSE' % (testScore))
# Out:
# 76/76 [==============================] - 1s 4ms/step
# Train Score: 0.22 RMSE

# %%
model = load_model('./models/my_model')

# Forecasting...
n_past = 24
n_hours_for_prediction = 1 # predict past 12 hours?
#print(train_hours.tail(24))
forecast_period_hours = pd.date_range(list(train_hours)[-n_past], periods=n_hours_for_prediction, freq='1H').tolist()

forecast = model.predict(trainX[-n_hours_for_prediction:])

prediction_copies = np.repeat(forecast, df_for_training_scaled.shape[1], axis=-1)
print('prediction_copies ', prediction_copies)
# prediction_copies  [[0.72134334 0.72134334 0.72134334 0.72134334]]
y_pred_future = scaler.inverse_transform(prediction_copies)[:, 0]
print('y_pred_future ', y_pred_future)
# y_pred_future  [10.993273]
# Out:
# 1/1 [==============================] - 0s 174ms/step
# prediction_copies  [[0.72252935 0.72252935 0.72252935]]
# y_pred_future  [11.011348]
