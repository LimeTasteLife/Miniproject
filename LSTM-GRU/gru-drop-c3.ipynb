# %%
import numpy as np
import pandas as pd
import seaborn as sns
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, GRU, Dropout
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MaxAbsScaler
from tensorflow.keras.optimizers import Adam
from sklearn.linear_model import Lasso

# Read data
df = pd.read_csv('data.csv')
# 쓸데없는 index 제거
df = df.drop(df.columns[0], axis=1)
#print(df.head())

train_hours = pd.to_datetime(df['_time'])
#print(train_hours.tail(15))

# moduleName = cosmos만 고르기
cosmos_df = df[df['chainName'] == "cosmos"]
#columns_to_keep = ['_time', 'cap', 'high24h', 'low24h', 'price','totalVolume', 'apr', 'bondedTokens', 'communityTokens', 'tps', 'priceBTC', 'Binance #01 (Deposit)-amountValue', 'Binance #02 (Deposit)-amountValue', 'Binance #03 (Withdraw)-amountValue', 'Binance #04 (Staking)-amountValue', 'Bitforex #01 (Deposit)-amountValue', 'Bithumb #02 (Withdraw)-amountValue', 'Bithumb #03-amountValue', 'Bithumb #05-amountValue', 'Coinbase #01-amountValue', 'Coinbase #03-amountValue', 'Coinbase #05-amountValue', 'Coinbase #06-amountValue', 'Coinbase #08-amountValue', 'Coinone #01(Deposit)-amountValue', 'Digfinex #01 (Deposit)-amountValue', 'DokiaCapital #01 (Validator)-amountValue', 'DokiaCapital #02 (Validator)-amountValue', 'HitBTC #02-amountValue', 'Ignite-amountValue', 'Interchain Foundation #01-amountValue', 'Interchain Foundation #02-amountValue', 'Kraken #01-amountValue', 'MEXC #01 (Deposit)-amountValue', 'OKK #01-amountValue', 'Upbit #01 (Deposit)-amountValue', 'Upbit #02 (Withdraw)-amountValue', 'Upbit #10 (Validator)-amountValue', 'Upbit #11 (Staking)-amountValue', 'Upbit #12 (Staking)-amountValue', 'Upbit #13 (Staking)-amountValue', 'Upbit #14 (Staking)-amountValue', 'Upbit #15 (Staking)-amountValue', 'Upbit #16 (Staking)-amountValue', 'Upbit #17 (Staking)-amountValue', 'Upbit #18 (Staking)-amountValue', 'Upbit #19 (Staking)-amountValue', 'Upbit #20 (Staking)-amountValue', 'bonded_tokens_pool-amountValue', 'distribution-amountValue', 'fee_collector-amountValue', 'gov-amountValue', 'not_bonded_tokens_pool-amountValue']
cosmos_df = cosmos_df.drop(columns=['chainName', 'ath', 'athDate', 'atl', 'atlDate', 'JUNO ATOM Pool-amountValue', 'JUNO NETA Pool-amountValue', 'JUNO OSMO Pool-amountValue',	'JUNO RAW Pool-amountValue',	'JUNO ATOM Pool-boxplot',	'JUNO NETA Pool-boxplot',	'JUNO OSMO Pool-boxplot',	'JUNO RAW Pool-boxplot'])
print(cosmos_df.shape)
# (2446, 5)
# Out:
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# (2446, 111)

# %%
# price col 위치 재조정.
cols = list(cosmos_df.columns)
cols.insert(1, cols.pop(cols.index('price')))
# Reindex the DataFrame
cosmos_df = cosmos_df.loc[:, cols]
#print(cosmos_df.head())

cols = list(cosmos_df)[1:cosmos_df.shape[1]]
#print(cols)
#print(cosmos_df.shape)

df_for_training = cosmos_df[cols].astype(float)
print(df_for_training.shape)

scaler = MaxAbsScaler()
scaler.fit(df_for_training)
df_for_training_scaled = scaler.transform(df_for_training)
print(df_for_training_scaled.shape)

# Lasso Regression for feature selection
lasso = Lasso(alpha=0.001)
lasso.fit(df_for_training_scaled, df_for_training_scaled)
print(df_for_training_scaled.shape)

# Use Lasso for feature selection
selected_features = np.where(lasso.coef_!=0)[0]

# Update your train data according to selected features
df_for_training_scaled_selected = df_for_training_scaled[:, selected_features]
# Out:
# (2446, 110)
# (2446, 110)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.772e-03, tolerance: 5.225e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.075e-03, tolerance: 5.259e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.926e-03, tolerance: 5.247e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.852e-03, tolerance: 5.246e-03
#   model = cd_fast.enet_coordinate_descent(
# (2446, 110)

# %%
trainX = []
trainY = []

n_future = 1 
n_past = 24 

# define the point to split the data into training and testing
split_point = int(df_for_training_scaled_selected.shape[0]*0.8) 

# construct training part
for i in range(n_past, split_point):
    trainX.append(df_for_training_scaled_selected[i - n_past:i, 0:df_for_training_scaled_selected.shape[1]])
    trainY.append(df_for_training_scaled_selected[i + n_future - 1:i + n_future, 0])

trainX, trainY = np.array(trainX), np.array(trainY)

print('trainX shape == {}.'.format(trainX.shape))
print('trainY shape == {}.'.format(trainY.shape))

# construct testing part
testX = []
testY = []

for i in range(split_point, len(df_for_training_scaled_selected) - n_future +1):
    testX.append(df_for_training_scaled_selected[i - n_past:i, 0:df_for_training_scaled_selected.shape[1]])
    testY.append(df_for_training_scaled_selected[i + n_future - 1:i + n_future, 0])

testX, testY = np.array(testX), np.array(testY)

print('testX shape == {}.'.format(testX.shape))
print('testY shape == {}.'.format(testY.shape))
# Out:
# trainX shape == (1932, 24, 479).
# trainY shape == (1932, 1).
# testX shape == (490, 24, 479).
# testY shape == (490, 1).

# %%
model = Sequential()
model.add(GRU(32, activation='tanh', input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(GRU(32, activation='tanh', return_sequences=False))
model.add(Dense(trainY.shape[1]))

optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mse')
model.summary()

# fit the model
history = model.fit(trainX, trainY, epochs=(trainX.shape[0]//24), batch_size=24, validation_split=0.1, verbose=1)

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()

# save the model to disk
model.save('./models/GRU-v3')
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 24, 32)            49248
#
#  gru_1 (GRU)                 (None, 32)                6336
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 55617 (217.25 KB)
# Trainable params: 55617 (217.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/80
# 73/73 [==============================] - 4s 24ms/step - loss: 0.0958 - val_loss: 0.0087
# Epoch 2/80
# 73/73 [==============================] - 1s 14ms/step - loss: 0.0025 - val_loss: 8.3192e-04
# Epoch 3/80
# 73/73 [==============================] - 1s 14ms/step - loss: 5.1203e-04 - val_loss: 5.5536e-04
# Epoch 4/80
# 73/73 [==============================] - 1s 14ms/step - loss: 3.1052e-04 - val_loss: 4.3857e-04
# Epoch 5/80
# 73/73 [==============================] - 1s 15ms/step - loss: 2.8128e-04 - val_loss: 4.2049e-04
# Epoch 6/80
# 73/73 [==============================] - 1s 14ms/step - loss: 2.1651e-04 - val_loss: 3.9312e-04
# Epoch 7/80
# 73/73 [==============================] - 1s 15ms/step - loss: 1.6839e-04 - val_loss: 6.4582e-04
# Epoch 8/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.7453e-04 - val_loss: 4.2573e-04
# Epoch 9/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.4696e-04 - val_loss: 4.4223e-04
# Epoch 10/80
# 73/73 [==============================] - 1s 15ms/step - loss: 1.2951e-04 - val_loss: 5.5135e-04
# Epoch 11/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.4821e-04 - val_loss: 3.8919e-04
# Epoch 12/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.3513e-04 - val_loss: 5.1670e-04
# Epoch 13/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.2802e-04 - val_loss: 7.2402e-04
# Epoch 14/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.2488e-04 - val_loss: 4.4929e-04
# Epoch 15/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.0141e-04 - val_loss: 4.6701e-04
# Epoch 16/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.2226e-04 - val_loss: 7.0310e-04
# Epoch 17/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.1253e-04 - val_loss: 6.2300e-04
# Epoch 18/80
# 73/73 [==============================] - 1s 15ms/step - loss: 1.0340e-04 - val_loss: 5.1009e-04
# Epoch 19/80
# 73/73 [==============================] - 1s 15ms/step - loss: 1.0773e-04 - val_loss: 6.2182e-04
# Epoch 20/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.1039e-04 - val_loss: 7.1139e-04
# Epoch 21/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.1652e-04 - val_loss: 4.6933e-04
# Epoch 22/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.1196e-04 - val_loss: 3.6857e-04
# Epoch 23/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.0878e-04 - val_loss: 5.3387e-04
# Epoch 24/80
# 73/73 [==============================] - 1s 15ms/step - loss: 1.0288e-04 - val_loss: 4.5366e-04
# Epoch 25/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.0995e-04 - val_loss: 4.3937e-04
# Epoch 26/80
# 73/73 [==============================] - 1s 15ms/step - loss: 9.0523e-05 - val_loss: 3.6896e-04
# Epoch 27/80
# 73/73 [==============================] - 1s 14ms/step - loss: 8.9307e-05 - val_loss: 4.5985e-04
# Epoch 28/80
# 73/73 [==============================] - 1s 14ms/step - loss: 8.2142e-05 - val_loss: 6.0852e-04
# Epoch 29/80
# 73/73 [==============================] - 1s 15ms/step - loss: 1.3824e-04 - val_loss: 3.4927e-04
# Epoch 30/80
# 73/73 [==============================] - 1s 14ms/step - loss: 9.6999e-05 - val_loss: 5.6698e-04
# Epoch 31/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.0885e-04 - val_loss: 8.1296e-04
# Epoch 32/80
# 73/73 [==============================] - 1s 14ms/step - loss: 9.7094e-05 - val_loss: 6.2705e-04
# Epoch 33/80
# 73/73 [==============================] - 1s 14ms/step - loss: 9.9683e-05 - val_loss: 3.4351e-04
# Epoch 34/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.1273e-04 - val_loss: 4.6553e-04
# Epoch 35/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.0039e-04 - val_loss: 0.0012
# Epoch 36/80
# 73/73 [==============================] - 1s 15ms/step - loss: 1.0594e-04 - val_loss: 4.8230e-04
# Epoch 37/80
# 73/73 [==============================] - 1s 14ms/step - loss: 8.2099e-05 - val_loss: 6.0428e-04
# Epoch 38/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.1448e-04 - val_loss: 5.4446e-04
# Epoch 39/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.1840e-04 - val_loss: 5.1746e-04
# Epoch 40/80
# 73/73 [==============================] - 1s 14ms/step - loss: 9.7618e-05 - val_loss: 4.1217e-04
# Epoch 41/80
# 73/73 [==============================] - 1s 15ms/step - loss: 1.0561e-04 - val_loss: 0.0010
# Epoch 42/80
# 73/73 [==============================] - 1s 15ms/step - loss: 1.6503e-04 - val_loss: 3.1993e-04
# Epoch 43/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.1549e-04 - val_loss: 4.7399e-04
# Epoch 44/80
# 73/73 [==============================] - 1s 14ms/step - loss: 7.4730e-05 - val_loss: 5.3036e-04
# Epoch 45/80
# 73/73 [==============================] - 1s 14ms/step - loss: 9.4290e-05 - val_loss: 9.1069e-04
# Epoch 46/80
# 73/73 [==============================] - 1s 15ms/step - loss: 1.3287e-04 - val_loss: 2.8859e-04
# Epoch 47/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.0403e-04 - val_loss: 4.4893e-04
# Epoch 48/80
# 73/73 [==============================] - 1s 15ms/step - loss: 1.5420e-04 - val_loss: 4.8079e-04
# Epoch 49/80
# 73/73 [==============================] - 1s 14ms/step - loss: 9.9626e-05 - val_loss: 3.0463e-04
# Epoch 50/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.2104e-04 - val_loss: 3.2158e-04
# Epoch 51/80
# 73/73 [==============================] - 1s 14ms/step - loss: 9.6251e-05 - val_loss: 5.9968e-04
# Epoch 52/80
# 73/73 [==============================] - 1s 15ms/step - loss: 8.2783e-05 - val_loss: 4.6757e-04
# Epoch 53/80
# 73/73 [==============================] - 1s 14ms/step - loss: 9.2208e-05 - val_loss: 3.4815e-04
# Epoch 54/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.1251e-04 - val_loss: 3.9737e-04
# Epoch 55/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.5035e-04 - val_loss: 5.9437e-04
# Epoch 56/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.4040e-04 - val_loss: 3.4462e-04
# Epoch 57/80
# 73/73 [==============================] - 1s 14ms/step - loss: 7.7506e-05 - val_loss: 2.7426e-04
# Epoch 58/80
# 73/73 [==============================] - 1s 16ms/step - loss: 1.1846e-04 - val_loss: 6.4979e-04
# Epoch 59/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.5316e-04 - val_loss: 4.6926e-04
# Epoch 60/80
# 73/73 [==============================] - 1s 14ms/step - loss: 2.6484e-04 - val_loss: 3.4190e-04
# Epoch 61/80
# 73/73 [==============================] - 1s 14ms/step - loss: 9.7080e-05 - val_loss: 3.9998e-04
# Epoch 62/80
# 73/73 [==============================] - 1s 14ms/step - loss: 7.7485e-05 - val_loss: 2.8518e-04
# Epoch 63/80
# 73/73 [==============================] - 1s 15ms/step - loss: 7.2285e-05 - val_loss: 2.6193e-04
# Epoch 64/80
# 73/73 [==============================] - 1s 14ms/step - loss: 8.9352e-05 - val_loss: 6.8348e-04
# Epoch 65/80
# 73/73 [==============================] - 1s 14ms/step - loss: 8.6232e-05 - val_loss: 2.8832e-04
# Epoch 66/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.1232e-04 - val_loss: 2.4403e-04
# Epoch 67/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.2004e-04 - val_loss: 2.9366e-04
# Epoch 68/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.2986e-04 - val_loss: 2.7735e-04
# Epoch 69/80
# 73/73 [==============================] - 1s 15ms/step - loss: 8.7248e-05 - val_loss: 4.8802e-04
# Epoch 70/80
# 73/73 [==============================] - 1s 15ms/step - loss: 1.5153e-04 - val_loss: 2.2889e-04
# Epoch 71/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.0182e-04 - val_loss: 2.3828e-04
# Epoch 72/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.2292e-04 - val_loss: 3.9457e-04
# Epoch 73/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.2209e-04 - val_loss: 4.2710e-04
# Epoch 74/80
# 73/73 [==============================] - 1s 15ms/step - loss: 1.0190e-04 - val_loss: 2.5091e-04
# Epoch 75/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.0706e-04 - val_loss: 3.1580e-04
# Epoch 76/80
# 73/73 [==============================] - 1s 14ms/step - loss: 8.7616e-05 - val_loss: 2.2209e-04
# Epoch 77/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.2214e-04 - val_loss: 2.4141e-04
# Epoch 78/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.3972e-04 - val_loss: 2.4089e-04
# Epoch 79/80
# 73/73 [==============================] - 1s 14ms/step - loss: 1.8649e-04 - val_loss: 1.9847e-04
# Epoch 80/80
# 73/73 [==============================] - 1s 15ms/step - loss: 1.3170e-04 - val_loss: 2.4211e-04
# INFO:tensorflow:Assets written to: ./models/GRU-v3/assets
# INFO:tensorflow:Assets written to: ./models/GRU-v3/assets

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# load the model from disk
model = load_model('./models/GRU-v3')

def evaluate_model(model, X, y_true, scaler, df_for_training):
    # Predict
    y_pred = model.predict(X)
    
    # Create dummy arrays for inverse transform
    dummy_pred = np.zeros((len(y_pred), df_for_training.shape[1]))
    dummy_true = np.zeros((len(y_true), df_for_training.shape[1]))
    
    # Replace the first column with predicted and actual values
    dummy_pred[:,0] = y_pred[:,0]
    dummy_true[:,0] = y_true[:,0]
    
    # Inverse transform
    y_pred_rescaled = scaler.inverse_transform(dummy_pred)[:,0]
    y_true_rescaled = scaler.inverse_transform(dummy_true)[:,0]
    
    # Calculate RMSE
    rmse = sqrt(mean_squared_error(y_true_rescaled, y_pred_rescaled))
    
    # Plot actual vs predicted values
    plt.figure(figsize=(15, 6))
    plt.plot(y_true_rescaled, label='Actual')
    plt.plot(y_pred_rescaled, label='Predicted')
    plt.title('Actual vs Predicted')
    plt.ylabel('Price')
    plt.legend()
    plt.show()
    
    return rmse

# Call the function
# trainScore = evaluate_model(model, trainX, trainY, scaler, df_for_training)
# print('Train Score: %.2f RMSE' % (trainScore))

# Call the function for testing data
testScore = evaluate_model(model, testX, testY, scaler, df_for_training)
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# 16/16 [==============================] - 0s 4ms/step
# Test Score: 0.35 RMSE
