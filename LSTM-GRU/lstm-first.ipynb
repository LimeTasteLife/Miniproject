# %%
import numpy as np
import pandas as pd
import seaborn as sns
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, LSTM, GRU, Dropout
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MaxAbsScaler

# Read data
df = pd.read_csv('data.csv')
# 쓸데없는 index 제거
df = df.drop(df.columns[0], axis=1)
#print(df.head())

train_hours = pd.to_datetime(df['_time'])
#print(train_hours.tail(15))

# moduleName = cosmos만 고르기
cosmos_df = df[df['chainName'] == "cosmos"]
columns_to_keep = ['_time', 'price', 'totalVolume', 'bondedTokens', 'tps']
cosmos_df = cosmos_df[columns_to_keep]
print(cosmos_df.shape)
# (2446, 5)
# Out:
# (2446, 5)

# %%
# Plot 'price' over '_time'
plt.figure(figsize=(15, 6))
plt.plot_date(cosmos_df['_time'], cosmos_df['price'], linestyle='solid', marker=None)
plt.title('Price over time')
plt.xlabel('Time')
plt.ylabel('Price')
plt.show()
# Out:
# /var/folders/rs/451vhmx909jbf4784zj52l980000gn/T/ipykernel_46407/863480140.py:3: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot_date(cosmos_df['_time'], cosmos_df['price'], linestyle='solid', marker=None)

# %%
# data normalizing
cols = list(cosmos_df)[1:5]
print(cols)
print(cosmos_df.shape)
#(2446, 5)

df_for_training = cosmos_df[cols].astype(float)
print(df_for_training.shape)
#(2446, 4)

scaler = MaxAbsScaler()
scaler.fit(df_for_training)
df_for_training_scaled = scaler.transform(df_for_training)
print(df_for_training_scaled.shape)
#(2446, 4)
# Out:
# ['price', 'totalVolume', 'bondedTokens', 'tps']
# (2446, 5)
# (2446, 4)
# MaxAbsScaler()
# (2446, 4)

# %%
trainX = []
trainY = []

n_future = 1
n_past = 24 # 24시간

for i in range(n_past, len(df_for_training_scaled) - n_future + 1):
    trainX.append(df_for_training_scaled[i - n_past:i, 0:df_for_training_scaled.shape[1]])
    trainY.append(df_for_training_scaled[i + n_future - 1:i + n_future, 0])
    
trainX, trainY = np.array(trainX), np.array(trainY)

print('trainX shape == {}.'.format(trainX.shape))
# (2422, 24, 4)
print('trainY shape == {}.'.format(trainY.shape))
# (2422, 1)
# ...
# Out:
# trainX shape == (2422, 24, 4).
# trainY shape == (2422, 1).

# %%
## 여기 shape 수정해야될 거 같은데.
model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(LSTM(32, activation='relu', return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(trainY.shape[1]))

model.compile(optimizer='adam', loss='mse')
model.summary()

# fit the model
history = model.fit(trainX, trainY, epochs=101, batch_size=24, validation_split=0.2, verbose=1)

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()

# save the model to disk
model.save('./models/my_model')
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_18 (LSTM)              (None, 24, 64)            17664
#
#  lstm_19 (LSTM)              (None, 32)                12416
#
#  dropout_9 (Dropout)         (None, 32)                0
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 30113 (117.63 KB)
# Trainable params: 30113 (117.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/101
# 81/81 [==============================] - 2s 14ms/step - loss: 0.0886 - val_loss: 0.0225
# Epoch 2/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0213 - val_loss: 0.0024
# Epoch 3/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0169 - val_loss: 0.0125
# Epoch 4/101
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0146 - val_loss: 0.0010
# Epoch 5/101
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0129 - val_loss: 8.6268e-04
# Epoch 6/101
# 81/81 [==============================] - 1s 17ms/step - loss: 0.0114 - val_loss: 3.1488e-04
# Epoch 7/101
# 81/81 [==============================] - 1s 15ms/step - loss: 0.0103 - val_loss: 4.7956e-04
# Epoch 8/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0108 - val_loss: 4.1182e-04
# Epoch 9/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0101 - val_loss: 4.7524e-04
# Epoch 10/101
# 81/81 [==============================] - 1s 15ms/step - loss: 0.0095 - val_loss: 4.8781e-04
# Epoch 11/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0084 - val_loss: 0.0015
# Epoch 12/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0085 - val_loss: 6.7402e-04
# Epoch 13/101
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0084 - val_loss: 2.2768e-04
# Epoch 14/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0078 - val_loss: 7.1385e-04
# Epoch 15/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0073 - val_loss: 5.5873e-04
# Epoch 16/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0074 - val_loss: 8.4095e-04
# Epoch 17/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0065 - val_loss: 4.7220e-04
# Epoch 18/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0065 - val_loss: 6.7631e-04
# Epoch 19/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0064 - val_loss: 2.4687e-04
# Epoch 20/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0063 - val_loss: 0.0014
# Epoch 21/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0057 - val_loss: 4.0753e-04
# Epoch 22/101
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0056 - val_loss: 3.6049e-04
# Epoch 23/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0055 - val_loss: 3.3321e-04
# Epoch 24/101
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0051 - val_loss: 3.0510e-04
# Epoch 25/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0044 - val_loss: 2.9258e-04
# Epoch 26/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0044 - val_loss: 1.9711e-04
# Epoch 27/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0039 - val_loss: 2.2683e-04
# Epoch 28/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0037 - val_loss: 3.8198e-04
# Epoch 29/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0036 - val_loss: 3.4848e-04
# Epoch 30/101
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0033 - val_loss: 2.1925e-04
# Epoch 31/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0031 - val_loss: 2.8512e-04
# Epoch 32/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0031 - val_loss: 2.9283e-04
# Epoch 33/101
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0028 - val_loss: 2.7079e-04
# Epoch 34/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0027 - val_loss: 3.1530e-04
# Epoch 35/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0024 - val_loss: 4.5042e-04
# Epoch 36/101
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0023 - val_loss: 2.7719e-04
# Epoch 37/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0024 - val_loss: 3.9189e-04
# Epoch 38/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0020 - val_loss: 4.3955e-04
# Epoch 39/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0020 - val_loss: 3.3214e-04
# Epoch 40/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0018 - val_loss: 3.8421e-04
# Epoch 41/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0017 - val_loss: 4.1933e-04
# Epoch 42/101
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0015 - val_loss: 3.7024e-04
# Epoch 43/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0014 - val_loss: 3.8229e-04
# Epoch 44/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0013 - val_loss: 2.7893e-04
# Epoch 45/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0013 - val_loss: 4.6293e-04
# Epoch 46/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0011 - val_loss: 3.8706e-04
# Epoch 47/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0011 - val_loss: 2.9860e-04
# Epoch 48/101
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0011 - val_loss: 4.5600e-04
# Epoch 49/101
# 81/81 [==============================] - 1s 13ms/step - loss: 9.0610e-04 - val_loss: 4.3572e-04
# Epoch 50/101
# 81/81 [==============================] - 1s 14ms/step - loss: 8.0100e-04 - val_loss: 3.1676e-04
# Epoch 51/101
# 81/81 [==============================] - 1s 13ms/step - loss: 7.7301e-04 - val_loss: 3.6769e-04
# Epoch 52/101
# 81/81 [==============================] - 1s 13ms/step - loss: 7.9777e-04 - val_loss: 4.3576e-04
# Epoch 53/101
# 81/81 [==============================] - 1s 13ms/step - loss: 7.0796e-04 - val_loss: 3.5045e-04
# Epoch 54/101
# 81/81 [==============================] - 1s 13ms/step - loss: 7.2508e-04 - val_loss: 3.2635e-04
# Epoch 55/101
# 81/81 [==============================] - 1s 13ms/step - loss: 7.1304e-04 - val_loss: 2.9194e-04
# Epoch 56/101
# 81/81 [==============================] - 1s 13ms/step - loss: 6.4062e-04 - val_loss: 3.1777e-04
# Epoch 57/101
# 81/81 [==============================] - 1s 13ms/step - loss: 6.1404e-04 - val_loss: 3.2046e-04
# Epoch 58/101
# 81/81 [==============================] - 1s 13ms/step - loss: 5.9267e-04 - val_loss: 4.1315e-04
# Epoch 59/101
# 81/81 [==============================] - 1s 13ms/step - loss: 5.1547e-04 - val_loss: 3.1197e-04
# Epoch 60/101
# 81/81 [==============================] - 1s 13ms/step - loss: 5.4428e-04 - val_loss: 3.7307e-04
# Epoch 61/101
# 81/81 [==============================] - 1s 13ms/step - loss: 5.0907e-04 - val_loss: 3.7211e-04
# Epoch 62/101
# 81/81 [==============================] - 1s 13ms/step - loss: 5.2592e-04 - val_loss: 3.9338e-04
# Epoch 63/101
# 81/81 [==============================] - 1s 13ms/step - loss: 4.9064e-04 - val_loss: 4.2205e-04
# Epoch 64/101
# 81/81 [==============================] - 1s 13ms/step - loss: 5.0439e-04 - val_loss: 2.9361e-04
# Epoch 65/101
# 81/81 [==============================] - 1s 13ms/step - loss: 4.5510e-04 - val_loss: 3.0327e-04
# Epoch 66/101
# 81/81 [==============================] - 1s 13ms/step - loss: 4.3556e-04 - val_loss: 3.2093e-04
# Epoch 67/101
# 81/81 [==============================] - 1s 14ms/step - loss: 4.8288e-04 - val_loss: 2.9182e-04
# Epoch 68/101
# 81/81 [==============================] - 1s 13ms/step - loss: 4.3997e-04 - val_loss: 2.7706e-04
# Epoch 69/101
# 81/81 [==============================] - 1s 13ms/step - loss: 4.3712e-04 - val_loss: 3.0785e-04
# Epoch 70/101
# 81/81 [==============================] - 1s 13ms/step - loss: 4.5015e-04 - val_loss: 2.0694e-04
# Epoch 71/101
# 81/81 [==============================] - 1s 13ms/step - loss: 4.2947e-04 - val_loss: 2.0890e-04
# Epoch 72/101
# 81/81 [==============================] - 1s 13ms/step - loss: 4.2250e-04 - val_loss: 2.4711e-04
# Epoch 73/101
# 81/81 [==============================] - 1s 14ms/step - loss: 4.1161e-04 - val_loss: 2.0791e-04
# Epoch 74/101
# 81/81 [==============================] - 1s 14ms/step - loss: 4.0972e-04 - val_loss: 2.6098e-04
# Epoch 75/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.8943e-04 - val_loss: 1.8847e-04
# Epoch 76/101
# 81/81 [==============================] - 1s 14ms/step - loss: 4.1670e-04 - val_loss: 2.0252e-04
# Epoch 77/101
# 81/81 [==============================] - 1s 14ms/step - loss: 4.3847e-04 - val_loss: 2.1309e-04
# Epoch 78/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.9126e-04 - val_loss: 2.2693e-04
# Epoch 79/101
# 81/81 [==============================] - 1s 13ms/step - loss: 4.5181e-04 - val_loss: 2.4130e-04
# Epoch 80/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.8809e-04 - val_loss: 1.9574e-04
# Epoch 81/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.8624e-04 - val_loss: 1.7316e-04
# Epoch 82/101
# 81/81 [==============================] - 1s 14ms/step - loss: 4.0021e-04 - val_loss: 1.7702e-04
# Epoch 83/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.7556e-04 - val_loss: 1.8016e-04
# Epoch 84/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.7764e-04 - val_loss: 2.2792e-04
# Epoch 85/101
# 81/81 [==============================] - 1s 14ms/step - loss: 4.1276e-04 - val_loss: 3.0675e-04
# Epoch 86/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.9166e-04 - val_loss: 1.8437e-04
# Epoch 87/101
# 81/81 [==============================] - 1s 14ms/step - loss: 3.9479e-04 - val_loss: 1.6622e-04
# Epoch 88/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.5513e-04 - val_loss: 2.5013e-04
# Epoch 89/101
# 81/81 [==============================] - 1s 14ms/step - loss: 3.5057e-04 - val_loss: 2.7468e-04
# Epoch 90/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.8034e-04 - val_loss: 1.6125e-04
# Epoch 91/101
# 81/81 [==============================] - 1s 14ms/step - loss: 3.6306e-04 - val_loss: 1.7720e-04
# Epoch 92/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.6859e-04 - val_loss: 1.7404e-04
# Epoch 93/101
# 81/81 [==============================] - 1s 14ms/step - loss: 3.6786e-04 - val_loss: 1.3555e-04
# Epoch 94/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.3040e-04 - val_loss: 1.5465e-04
# Epoch 95/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.4499e-04 - val_loss: 1.2239e-04
# Epoch 96/101
# 81/81 [==============================] - 1s 13ms/step - loss: 4.3838e-04 - val_loss: 1.1949e-04
# Epoch 97/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.3122e-04 - val_loss: 1.4243e-04
# Epoch 98/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.4044e-04 - val_loss: 1.2061e-04
# Epoch 99/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.3185e-04 - val_loss: 1.0919e-04
# Epoch 100/101
# 81/81 [==============================] - 1s 14ms/step - loss: 3.6706e-04 - val_loss: 1.8950e-04
# Epoch 101/101
# 81/81 [==============================] - 1s 13ms/step - loss: 3.2263e-04 - val_loss: 1.2831e-04
# INFO:tensorflow:Assets written to: ./models/my_model/assets
# INFO:tensorflow:Assets written to: ./models/my_model/assets

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# load the model from disk
model = load_model('./models/my_model')

def evaluate_model(model, X, y_true, scaler, df_for_training):
    # Predict
    y_pred = model.predict(X)
    
    # Create dummy arrays for inverse transform
    dummy_pred = np.zeros((len(y_pred), df_for_training.shape[1]))
    dummy_true = np.zeros((len(y_true), df_for_training.shape[1]))
    
    # Replace the first column with predicted and actual values
    dummy_pred[:,0] = y_pred[:,0]
    dummy_true[:,0] = y_true[:,0]
    
    # Inverse transform
    y_pred_rescaled = scaler.inverse_transform(dummy_pred)[:,0]
    y_true_rescaled = scaler.inverse_transform(dummy_true)[:,0]
    
    # Calculate RMSE
    rmse = sqrt(mean_squared_error(y_true_rescaled, y_pred_rescaled))
    
    # Plot actual vs predicted values
    plt.figure(figsize=(15, 6))
    plt.plot(y_true_rescaled, label='Actual')
    plt.plot(y_pred_rescaled, label='Predicted')
    plt.title('Actual vs Predicted')
    plt.ylabel('Price')
    plt.legend()
    plt.show()
    
    return rmse

# Call the function
trainScore = evaluate_model(model, trainX, trainY, scaler, df_for_training)
print('Train Score: %.2f RMSE' % (trainScore))

# If you also have a test dataset, you can do:
# testPredict = model.predict(testX)
# testPredict = scaler.inverse_transform(testPredict)
# testY_true = scaler.inverse_transform(testY)
# testScore = sqrt(mean_squared_error(testY_true, testPredict))
# print('Test Score: %.2f RMSE' % (testScore))
# Out:
# 76/76 [==============================] - 0s 3ms/step
# Train Score: 0.17 RMSE

# %%
model = load_model('./models/my_model')

# Forecasting...
n_past = 24
n_hours_for_prediction = 1 # predict past 12 hours?
#print(train_hours.tail(24))
forecast_period_hours = pd.date_range(list(train_hours)[-n_past], periods=n_hours_for_prediction, freq='1H').tolist()

forecast = model.predict(trainX[-n_hours_for_prediction:])

prediction_copies = np.repeat(forecast, df_for_training_scaled.shape[1], axis=-1)
print('prediction_copies ', prediction_copies)
# prediction_copies  [[0.72134334 0.72134334 0.72134334 0.72134334]]
y_pred_future = scaler.inverse_transform(prediction_copies)[:, 0]
print('y_pred_future ', y_pred_future)
# y_pred_future  [10.993273]
# Out:
# 1/1 [==============================] - 0s 239ms/step
# prediction_copies  [[0.72134334 0.72134334 0.72134334 0.72134334]]
# y_pred_future  [10.993273]

# %%
from datetime import datetime

forecast_hours = []
for time_i in forecast_period_hours:
    forecast_hours.append(time_i.strftime('%Y-%m-%d %H'))

df_forecast = pd.DataFrame({'_time': np.array(forecast_hours), 'price': y_pred_future})
print(df_forecast.shape)
print(df_forecast.head())
# (1, 2)
df_forecast['_time'] = pd.to_datetime(df_forecast['_time'])

original = cosmos_df[['_time', 'price']]
print(original.shape)
# (2446, 2)
# print(original.tail())
# 2023-05-8 02:00:00+00:00  10.993273
original.loc[:,('_time')] = pd.to_datetime(original['_time'])
original = original.loc[original['_time'] >= pd.Timestamp("2023-01-24 21:00:00+00:00")]
print(original.shape)
# (2446, 2)

print(original['price'].dtype)
print(df_forecast['price'].dtype)
original['price'] = original['price'].astype(float)
df_forecast['price'] = df_forecast['price'].astype(float)

sns.lineplot(data=original, x="_time", y="price")
sns.lineplot(data=df_forecast, x="_time", y="price")
# Out:
# (1, 2)
#            _time      price
# 0  2023-05-07 03  10.993273
# (2446, 2)
# (2446, 2)
# float64
# float32
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[151], line 28
#      25 original['price'] = original['price'].astype(float)
#      26 df_forecast['price'] = df_forecast['price'].astype(float)
# ---> 28 sns.lineplot(data=original, x="_time", y="price")
#      29 sns.lineplot(data=df_forecast, x="_time", y="price")
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/seaborn/relational.py:710, in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     706     return ax
#     708 p._attach(ax)
# --> 710 p.plot(ax, kwargs)
#     711 return ax
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/seaborn/relational.py:471, in _LinePlotter.plot(self, ax, kws)
#     469 # Loop over the semantic subsets and add to the plot
#     470 grouping_vars = "hue", "size", "style"
# --> 471 for sub_vars, sub_data in self.iter_data(grouping_vars, from_comp_data=True):
#     473     if self.sort:
#     474         sort_vars = ["units", "x", "y"]
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:983, in VectorPlotter.iter_data(self, grouping_vars, reverse, from_comp_data)
#     978 grouping_vars = [
#     979     var for var in grouping_vars if var in self.variables
#     980 ]
#     982 if from_comp_data:
# --> 983     data = self.comp_data
#     984 else:
#     985     data = self.plot_data
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1054, in VectorPlotter.comp_data(self)
#    1050 axis = getattr(ax, f"{var}axis")
#    1052 # Use the converter assigned to the axis to get a float representation
#    1053 # of the data, passing np.nan or pd.NA through (pd.NA becomes np.nan)
# -> 1054 with pd.option_context('mode.use_inf_as_null', True):
#    1055     orig = self.plot_data[var].dropna()
#    1056 comp_col = pd.Series(index=orig.index, dtype=float, name=var)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/_config/config.py:441, in option_context.__enter__(self)
#     440 def __enter__(self) -> None:
# --> 441     self.undo = [(pat, _get_option(pat, silent=True)) for pat, val in self.ops]
#     443     for pat, val in self.ops:
#     444         _set_option(pat, val, silent=True)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/_config/config.py:441, in <listcomp>(.0)
#     440 def __enter__(self) -> None:
# --> 441     self.undo = [(pat, _get_option(pat, silent=True)) for pat, val in self.ops]
#     443     for pat, val in self.ops:
#     444         _set_option(pat, val, silent=True)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/_config/config.py:135, in _get_option(pat, silent)
#     134 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 135     key = _get_single_key(pat, silent)
#     137     # walk the nested dict
#     138     root, k = _get_root(key)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/_config/config.py:121, in _get_single_key(pat, silent)
#     119     if not silent:
#     120         _warn_if_deprecated(pat)
# --> 121     raise OptionError(f"No such keys(s): {repr(pat)}")
#     122 if len(keys) > 1:
#     123     raise OptionError("Pattern matched multiple keys")
#
# OptionError: "No such keys(s): 'mode.use_inf_as_null'"
